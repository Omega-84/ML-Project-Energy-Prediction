# %% [markdown]
# # **Data-driven prediction of energy use of appliances**
#
# **The data set is at 10 min for about 4.5 months. The house temperature and humidity conditions were monitored with a ZigBee wireless sensor network. Each wireless node transmitted the temperature and humidity conditions around 3.3 min. Then, the wireless data was averaged for 10 minutes periods. The energy data was logged every 10 minutes with m-bus energy meters. Weather from the nearest airport weather station Chievres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis (rp5.ru) and merged together with the experimental data sets using the date and time column. Two random variables have been included in the data set for testing the regression models and to filter out non-predictive attributes (parameters).**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from warnings import filterwarnings
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
from sklearn import neighbors
from sklearn.svm import SVR
import time
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score,KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras import Sequential, layers, Input
import tensorflow as tf
filterwarnings("ignore")
plt.style.use('ggplot')

# %%
df = pd.read_csv('data_application_energy.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# **Number of entries : 19735 <br> No of features : 27 ( 2 Random Variables included )<br> Target Variable : Appliances <br> All features are numerical. No categorical variables. There seems to be no null values in our data set.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **No duplicate entries are present**

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %% [markdown]
# ## We have 10 features carrying information about the temperature at various locations in and around households

# %%
temp_dict = {
    'T1' : 'temp_kitchen', 'T2' : 'temp_living', 'T3' : 'temp_laundry', 
    'T4' : 'temp_office', 'T5' : 'temp_bath', 'T6' : 'temp_outside',
    'T7' : 'temp_iron', 'T8' : 'temp_teen', 'T9' : 'temp_parents', 'T_out' : 'temp_station'
}

# %%
energy_df = df.rename(columns=temp_dict)

# %% [markdown]
# ## We have 10 features carrying information about the humidity at various locations in and around households

# %%
humid_dict = {
    'RH_1' : 'humid_kitchen', 'RH_2' : 'humid_living', 'RH_3' : 'humid_laundry', 
    'RH_4' : 'humid_office', 'RH_5' : 'humid_bath', 'RH_6' : 'humid_outside',
    'RH_7' : 'humid_iron', 'RH_8' : 'humid_teen', 'RH_9' : 'humid_parents', 'RH_out' : 'humid_station'
}

# %%
energy_df.rename(columns=humid_dict,inplace=True)

# %%
energy_df[temp_dict.values()].describe()
# Out:
#        temp_kitchen   temp_living  temp_laundry   temp_office     temp_bath  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      21.686571     20.341219     22.267611     20.855335     19.592106
# std        1.606066      2.192974      2.006111      2.042884      1.844623
# min       16.790000     16.100000     17.200000     15.100000     15.330000
# 25%       20.760000     18.790000     20.790000     19.530000     18.277500
# 50%       21.600000     20.000000     22.100000     20.666667     19.390000
# 75%       22.600000     21.500000     23.290000     22.100000     20.619643
# max       26.260000     29.856667     29.236000     26.200000     25.795000
#
#        temp_outside     temp_iron     temp_teen  temp_parents  temp_station
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       7.910939     20.267106     22.029107     19.485828      7.411665
# std        6.090347      2.109993      1.956162      2.014712      5.317409
# min       -6.065000     15.390000     16.306667     14.890000     -5.000000
# 25%        3.626667     18.700000     20.790000     18.000000      3.666667
# 50%        7.300000     20.033333     22.100000     19.390000      6.916667
# 75%       11.256000     21.600000     23.390000     20.600000     10.408333
# max       28.290000     26.000000     27.230000     24.500000     26.100000

# %% [markdown]
# **OBSERVATIONS** : <br>
# 1. **Average outside temperature over a period of 4.5 months is around 7.3 degrees. It ranges from -6 to  +28 degrees**
# 2. **While average temperature inside the building has been around 20 degrees for all the rooms. It ranges from 14 to 30 degrees**
# 3. **Which implies, Warming appliances have been used to keep the insides of the building warm. There must be some sort of strong correlation between temperature and consumption of energy inside house.**

# %%
energy_df[humid_dict.values()].describe()
# Out:
#        humid_kitchen  humid_living  humid_laundry  humid_office    humid_bath  \
# count   19735.000000  19735.000000   19735.000000  19735.000000  19735.000000
# mean       40.259739     40.420420      39.242500     39.026904     50.949283
# std         3.979299      4.069813       3.254576      4.341321      9.022034
# min        27.023333     20.463333      28.766667     27.660000     29.815000
# 25%        37.333333     37.900000      36.900000     35.530000     45.400000
# 50%        39.656667     40.500000      38.530000     38.400000     49.090000
# 75%        43.066667     43.260000      41.760000     42.156667     53.663333
# max        63.360000     56.026667      50.163333     51.090000     96.321667
#
#        humid_outside    humid_iron    humid_teen  humid_parents  humid_station
# count   19735.000000  19735.000000  19735.000000   19735.000000   19735.000000
# mean       54.609083     35.388200     42.936165      41.552401      79.750418
# std        31.149806      5.114208      5.224361       4.151497      14.901088
# min         1.000000     23.200000     29.600000      29.166667      24.000000
# 25%        30.025000     31.500000     39.066667      38.500000      70.333333
# 50%        55.290000     34.863333     42.375000      40.900000      83.666667
# 75%        83.226667     39.000000     46.536000      44.338095      91.666667
# max        99.900000     51.400000     58.780000      53.326667     100.000000

# %% [markdown]
# **OBSERVATIONS :**
# 1. **Average humidity outside the building has been higher than the average humidity inside.**
# 2. **Average humidity at the weather station is significantly higher compared to outside humidity near the building.**
# 3. **Average humidity in the bathroom is significantly higher compared to other rooms due to obvious reasons.**
# 4. **Kids and parent room show a comparatively higher average humidity as well signifying the fact that, inhabitants of this building spend most of their time in these buildings.**

# %%
weather_cols = list(set(energy_df.columns) - set(list(temp_dict.values())) - set(list(humid_dict.values())) - {'Appliances', 'lights', 'rv1', 'rv2'})
weather_cols
# Out:
# ['Windspeed', 'date', 'Press_mm_hg', 'Tdewpoint', 'Visibility']

# %% [markdown]
# ## The remaining features carry information about the weather conditions

# %%
df.Appliances.describe()
# Out:
# count    19735.000000
# mean        97.694958
# std        102.524891
# min         10.000000
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1080.000000
# Name: Appliances, dtype: float64

# %%
sns.histplot(df['Appliances'],bins=50)
plt.ylabel("");

# %% [markdown]
# **75% of Appliance consumption is less than 100 Wh . With the maximum consumption of 1080 Wh , there will be outliers in this column and there are small number of cases where consumption is very high**

# %%
df.lights.value_counts()
# Out:
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 70        1
# 60        1
# Name: lights, dtype: int64

# %% [markdown]
# **Since most of the value in lights column is 0, it wont be playing much role in our model. Hence we drop the lights feature from our dataframe.**

# %%
energy_df.drop('lights', axis=1,inplace=True)

# %% [markdown]
# ### **Energy consumption**

# %% [markdown]
# **Energy Consumption pattern of the household at different times of the day over different time periods**

# %%
energy_df['weekday'] = ((pd.to_datetime(energy_df['date']).dt.dayofweek)// 5 == 0).astype(int)
energy_df['hour'] = pd.to_datetime(energy_df['date']).dt.hour
energy_df['month'] = pd.to_datetime(energy_df['date']).dt.month

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
energy_df.groupby('hour')['Appliances'].mean().plot.bar(ax=ax)
ax.set_ylabel('Appliance energy (Wh)')
plt.legend(['Appliances'],loc='best',fontsize=14);

# %% [markdown]
# **Above figure is a representation of average energy consumption of appliances at different time of the day over a period of 4.5 months. We observe two peak hours. One at 11 am in the morning and other at 6 PM in the evening. While the peak at 11 am is shallow and low, peak at 6 PM is comparatively higher and sharper.**
#
# **We observe that over the sleeping hours (10 PM - 6 AM) the energy consumption of appliances is around 50 Wh. After about 6 AM, energy consumption starts to rise gradually up until 11 AM (probably due to morning chores). And then gradually decreases to around 100 Wh at about 3 PM. After which the energy consumption drastically shoots up up until 6 PM in the evening (probably due to requirement lights in rooms). However energy consumption of appliances reverts back to 50 Wh, as night approaches and people in the house go to bed at around 10 PM.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour'])['Appliances'].mean().plot.bar(ax=ax)
ax.set_ylabel('Appliance enrergy (Wh)')
plt.legend(['Appliances'],loc='best',fontsize=14);

# %% [markdown]
# **A trend of high consumption hours for each month seems to be similar to the over all trend**
#
# **What about weekdays and weekends?**

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
week_df = energy_df.groupby(['weekday','hour']).agg({'Appliances':'mean'}).reset_index(0)
week_df[week_df.weekday==0].Appliances.plot.bar(ax=ax[0], label='weekends')
week_df[week_df.weekday==1].Appliances.plot.bar(ax=ax[1], label='weekdays')
ax[0].legend(loc='best',fontsize=12)
ax[1].legend(loc='best',fontsize=12)
ax[0].set_ylabel('Appliance Energy (Wh)')
ax[1].set_ylabel('Appliance Energy (Wh)');

# %% [markdown]
# **We observe that the energy consumption of appliances during the office hours (8 AM - 4 PM) is higher in weekends compared to the weekdays. Also, average overall consumption is higher in weekends**
#
# **Lets look at how temperature and humidity levels vary inside different rooms !**
#
# ### **Temperature levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
    energy_df.groupby('hour')[temp].mean().plot.bar(ax=axes[i//5, i%5])
    axes[i//5, i%5].legend(loc='best')
    axes[i//5, i%5].set_title(temp);

# %% [markdown]
# **The average temperature inside each of the rooms has been almost constant over the day. However the average temperature outside the building and near the station changes over the course of the day. The average night time temperature is around 6 degree C, while average day time temperature varies over hours and peaks to 12 degree C at about 2-3 PM in the afternoon.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour'])['temp_outside'].mean().plot.bar(ax=ax)
plt.legend(['temp_outside'],loc='best',fontsize=14);

# %% [markdown]
# ## The average temperature outside started rising over the months which indicates the data is from spring season

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
    energy_df.groupby('month')[humid].mean().plot.bar(ax=axes[i//5, i%5])
    axes[i//5, i%5].legend(loc='best')
    axes[i//5, i%5].set_title(humid)

# %% [markdown]
# **Although the humidity outside building tend to decrease over months, the humidity inside rooms seem to be unaffected. The humidity levels outside seem to be negatively correlated to with the temperature levels outside. Lets check !**

# %%
energy_df[['temp_outside', 'humid_outside']].corr()
# Out:
#                temp_outside  humid_outside
# temp_outside       1.000000      -0.672137
# humid_outside     -0.672137       1.000000

# %% [markdown]
# **Indeed there is a strong negative correlation between temperature and humidity levels outside. As temperature increases, moisture levels in the air decreases. We also observe that during the day time when the temperatures are high, humidity levels are low.**

# %% [markdown]
# **Lets look at correlation matrix of temperature and humidity levels**

# %%
cols = list(temp_dict.values())
cols.extend(list(humid_dict.values()))
cols.extend(['Appliances'])
fig, ax = plt.subplots(1,1,figsize=(15,15))
sns.heatmap(energy_df[cols].corr(), ax=ax, annot=True,cmap='RdYlBu');

# %% [markdown]
# **OBSERVATIONS :**
#
# * **From the correlation graph we clearly observe that the features related to temperature and features related to humidity have positive correlation within themselves whereas have a a very little to no correlation with each other.**
# * **Humidity outside have a strong negative correlation with temperature levels as already discussed.**
# * **Apart from that we observe that a couple features such as humidity at station, temperature outside the building and temperature in the living room have a comparatively high absolute correlation (above 0.12) with Appliances energy consumption.**

# %%
# let us plot the variation of energy consumption with these variables
fig, axes = plt.subplots(4,5,figsize = (50,40))
for i, col in enumerate(cols[:-1]):
    ax = axes[i//5, i%5]
    ax.scatter(energy_df[col], energy_df['Appliances'])
    ax.set_xlabel(col)
    ax.set_ylabel('Appliances');

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['month', 'weekday', 'hour', 'Appliances']].corr(), annot=True, ax=ax);

# %% [markdown]
# * **As we have observed earlier as well, there seenms to be no correlation between month and the observed energy use i.e. the enegy consumption pretty much remains similar over all months. Similarly there is no direct effect of weekdays on appliance energy consumption.**
# * **Although there is a correlation of 0.22 between hour and appliances**

# %%
def create_session(x):
    if x <= 6 or x >= 22:
        return 1
    elif x>6 and x <=15:
        return 2
    else:
        return 3

# %%
# lets create a new column based on our observations
energy_df['session'] = energy_df['hour'].apply(lambda x : create_session(x))

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['session', 'Appliances']].corr(), ax = ax, annot=True);

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sns.boxplot(x='session',y='Appliances',data=energy_df, ax = ax);

# %% [markdown]
# **We were now able to increase the correlation to 0.34 by making creating this new row. We see a clear distinction of power consumtion in different sessions.**
#
# **Lets look at features related to weather as well.**

# %%
fig,ax = plt.subplots(1,1,figsize=(20,15))
sns.heatmap(energy_df[weather_cols + cols].corr(), ax = ax, annot=True,cmap='RdYlBu');

# %% [markdown]
# **Tdewpoint shows a high correlation with most of the tempearture and humidity level features than any other weather parameters. Pressure, windspeed and visibiltiy show little to no correlation. We might need to include these only these feaatures in our final model**
#
# **Lets now deep dive into reducing the temperature and humidity parameters through some feature engineering and come up with features that explain maximum variability.**

# %%
temp_cols = list(set(list(temp_dict.values())) - {'temp_outside', 'temp_station'})
energy_df['mean_temp'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_temp', 'Appliances']].corr()
# Out:
#             mean_temp  Appliances
# mean_temp     1.00000     0.05474
# Appliances    0.05474     1.00000

# %% [markdown]
# **Since most of the temperature variables inside the room show little to know correlation with target variable, lets try to find components that could explain maximum variance, which might improve the correlation with target variable as well.**

# %% [markdown]
# **Before doing PCA, I need to split the data into train and test, and fit PCA on train set to avoid data leakage**

# %%
train_energy_df, test_energy_df = train_test_split(energy_df, test_size=0.2, random_state=1)

# %%
pca = PCA()
pca.fit(train_energy_df[temp_cols])
temp_pca = pca.transform(energy_df[temp_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(1,len(variance)+1), variance,color='blue')
ax.plot(range(1,len(variance)+1), np.cumsum(variance),'o-',linewidth=2, label='Cummulative variance %',color='red')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best');

# %%
variance
# Out:
# array([84.42749838,  7.33014216,  2.3562388 ,  2.09550508,  1.47195967,
#         1.21891325,  0.69977714,  0.39996553])

# %% [markdown]
# First two components seem to explain more than 91 % of variance in data.

# %%
for i in range(temp_pca.shape[1]):
    energy_df[f'temp_pca{i+1}'] = temp_pca[:,i]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(energy_df[['temp_pca1', 'temp_pca2', 'temp_pca3', 'temp_pca4','temp_pca5', 'temp_pca6', 'temp_pca7', 'temp_pca8', 'Appliances']].corr(), annot=True,cmap='Blues');

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))
for i, j in enumerate((6,8)):
    axes[i].scatter(energy_df[f'temp_pca{j}'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(temp_cols, pca.components_[7,:]))
# Out:
# {'temp_parents': 0.6025874320322253,
#  'temp_living': -0.1173630470398786,
#  'temp_kitchen': 0.625202091839308,
#  'temp_bath': -0.21732855159144726,
#  'temp_iron': -0.24026540991588563,
#  'temp_office': -0.09845473026092949,
#  'temp_laundry': -0.2968959599105859,
#  'temp_teen': -0.1715719523850314}

# %% [markdown]
# ### **PCA on humidity**

# %%
humid_cols = list(set(list(humid_dict.values())) - {'humid_outside', 'humid_station'})
energy_df['mean_humid'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_humid', 'Appliances']].corr()
# Out:
#             mean_humid  Appliances
# mean_humid     1.00000     0.05474
# Appliances     0.05474     1.00000

# %%
pca.fit(train_energy_df[humid_cols])
humid_pca = pca.transform(energy_df[humid_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(1,len(variance)+1), variance,color='blue')
ax.plot(range(1,len(variance)+1), np.cumsum(variance),'o-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best');

# %%
variance
# Out:
# array([62.09137315, 28.02035975,  3.84761759,  2.19313449,  1.40502588,
#         1.22143306,  0.64956943,  0.57148664])

# %%
for i in range(humid_pca.shape[1]):
    energy_df[f'humid_pca{i+1}'] = humid_pca[:,i]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(energy_df[['humid_pca1', 'humid_pca2', 'humid_pca3', 'humid_pca4', 'humid_pca6', 'humid_pca7', 'humid_pca8', 'Appliances']].corr(), annot=True,cmap='Blues');

# %% [markdown]
# ### Strongest correlation with humid_pca4

# %%
plt.scatter(energy_df['humid_pca4'], energy_df['Appliances'])
plt.xlabel("humid_pca4")
plt.ylabel("Appliances");

# %%
#Lets look at components of humid_pca4
dict(zip(humid_cols, pca.components_[3,:]))
# Out:
# {'humid_iron': 0.0789769451298023,
#  'humid_teen': -0.5285334448509876,
#  'humid_kitchen': 0.41231222842688864,
#  'humid_living': -0.5395785231761459,
#  'humid_laundry': 0.2908803708815102,
#  'humid_parents': -0.018904279237056676,
#  'humid_office': 0.41021262197258834,
#  'humid_bath': -0.005052352457213902}

# %%
energy_df['diff_temp'] = energy_df['temp_outside'] - energy_df['mean_temp']
energy_df[['diff_temp', 'Appliances']].corr()
# Out:
#             diff_temp  Appliances
# diff_temp     1.00000     0.12411
# Appliances    0.12411     1.00000

# %%
energy_df['log_Appliances'] = np.log(energy_df['Appliances'])
sns.histplot(energy_df.log_Appliances,bins=50);

# %% [markdown]
# # **Modeling with PCA features**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
plt.figure(figsize=(8,6))
sns.heatmap(energy_df[final_features].corr(), annot=True,cmap='Blues');

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
y_train = sc_X.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_X.transform(y_test.values.reshape([-1,1])).flatten()

# %% [markdown]
# **The ML regressor models that we use are :**
# * **Lasso Regressor**
# * **Ridge Regressor**
# * **KNeighbors Regressor**
# * **Support Vector Regressor**
# * **Random Forest Regressor**
# * **Extra Tree Regressor**
# * **Gradient Boosting Regressor**
# * **XGB Regressor**
# * **MLP Regressor**

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()] ,
           ['XGBRegressor: ', xgb.XGBRegressor()] ,
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time (sec)"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)

# %%
results_df = pd.DataFrame(model_data)
results_df
# Out:
#                           Name  Train_Time (sec)  Train_R2_Score  \
# 0                      Lasso:           0.027298        0.000000
# 1                      Ridge:           0.057011        0.115048
# 2        KNeighborsRegressor:           0.026007        0.682389
# 3                         SVR:          8.736001        0.174908
# 4                RandomForest           9.918750        0.938959
# 5         ExtraTreeRegressor :          2.958421        1.000000
# 6  GradientBoostingRegressor:           2.968945        0.271858
# 7               XGBRegressor:           0.640666        0.781312
# 8               MLPRegressor:           4.673781        0.325954
#
#    Test_R2_Score  Test_RMSE_Score
# 0      -0.000777         1.028791
# 1       0.124513         0.962240
# 2       0.473707         0.746057
# 3       0.142802         0.952136
# 4       0.559954         0.682193
# 5       0.641419         0.615817
# 6       0.217850         0.909501
# 7       0.439300         0.770058
# 8       0.260662         0.884260

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8));

# %% [markdown]
# **OBSERVATIONS :**
#
# * **Extra Tree Regressor performs the best so far with a R2 score of 1 and RMSE of 0.64 but is overfit**
# * **Lasso is the worst performing model so far.**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 250}

# %%
best_model = grid_search.best_estimator_

# %%
best_model.score(X_train,y_train)
# Out:
# 1.0

# %%
best_model.score(X_test,y_test)
# Out:
# 0.6420092203610108

# %%
np.sqrt(mean_squared_error(y_test, best_model.predict(X_test)))
# Out:
# 0.6153103158401956

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_X.scale_ + sc_X.mean_, label='actual')
plt.plot(range(len(y_test[:200])), best_model.predict(X_test.iloc[:200,:])*sc_X.scale_ + sc_X.mean_, label='predicted')
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples');

# %%
feature_indices = np.argsort(best_model.feature_importances_)
importances = best_model.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show();

# %% [markdown]
# **Looking at the feature importances, it is clear that the PCA features of temperature and humidity hold slightly higher feature importances compared to others. However almost all the features used for modelling hold equal importance**

# %% [markdown]
# # **Modeling Without PCA features**
#
# **Including all temperature and humidity features and engineered feature 'session' in our features set.**

# %%
final_features = ['temp_laundry','temp_bath', 'temp_kitchen', 'temp_parents', 'temp_office', 'temp_living', 'temp_teen', 'temp_iron','humid_kitchen',
 'humid_office', 'humid_bath', 'humid_living', 'humid_parents', 'humid_laundry', 'humid_teen', 'humid_iron',
  'temp_outside', 'humid_outside', 'temp_station', 'humid_station', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
y_train = sc_X.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_X.transform(y_test.values.reshape([-1,1])).flatten()

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time (sec)"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)

# %%
results_df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time (sec)  Train_R2_Score  \
# 0                      Lasso:           0.205971        0.000000
# 1                      Ridge:           0.558710        0.181416
# 2        KNeighborsRegressor:           0.033370        0.680567
# 3                         SVR:          8.571680        0.269581
# 4                RandomForest          23.496929        0.942189
# 5         ExtraTreeRegressor :          6.469158        1.000000
# 6  GradientBoostingRegressor:           5.823934        0.349433
# 7               XGBRegressor:           0.812553        0.834172
# 8               MLPRegressor:           7.485300        0.477803
#
#    Test_R2_Score  Test_RMSE_Score
# 0      -0.000777         1.028791
# 1       0.185596         0.928064
# 2       0.485171         0.737887
# 3       0.242499         0.895055
# 4       0.593457         0.655709
# 5       0.644521         0.613148
# 6       0.271252         0.877904
# 7       0.483142         0.739339
# 8       0.397394         0.798316

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8));

# %% [markdown]
# **ExtraTreesRegressor again performed better than others**

# %%
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
best_model = grid_search.best_estimator_

# %%
best_model.score(X_train,y_train)
# Out:
# 1.0

# %%
best_model.score(X_test,y_test)
# Out:
# 0.6453971723995422

# %%
np.sqrt(mean_squared_error(y_test, best_model.predict(X_test)))
# Out:
# 0.6123918084485078

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_X.scale_ + sc_X.mean_ < 300]*sc_X.scale_ + sc_X.mean_, best_model.predict(X_test[y_test*sc_X.scale_ + sc_X.mean_ < 300,:])*sc_X.scale_ + sc_X.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_X.scale_ + sc_X.mean_ > 300]*sc_X.scale_ + sc_X.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_X.scale_ + sc_X.mean_ > 300,:])*sc_X.scale_ + sc_X.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5,color='blue')
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_X.scale_ + sc_X.mean_, grid_search.best_estimator_.predict(X_test)*sc_X.scale_ + sc_X.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best');

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_X.scale_ + sc_X.mean_, label='actual',linewidth=2)
plt.plot(range(len(y_test[:200])), best_model.predict(X_test.iloc[:200,:])*sc_X.scale_ + sc_X.mean_, label='predicted',linewidth=2)
plt.legend(loc='best',fontsize=14)
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples');

# %% [markdown]
# **The above figure represents actual and predicted values of 200 samples in test set.**

# %%
feature_indices = np.argsort(best_model.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **In the case where we don't include any PCA features, the engineered feature 'session' seems to hold most importance among all the features.**

# %% [markdown]
# # Neural Networks

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'session', 'Windspeed', 'Press_mm_hg', 'weekday', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
y_train = sc_X.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_X.transform(y_test.values.reshape([-1,1])).flatten()

# %%
def R_squared(y_true, y_pred):
    unexplained_error = tf.reduce_sum(tf.square(y_true - y_pred))
    total_error = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=0)))
    R2 = 1. - tf.truediv(unexplained_error, total_error)
    return R2

# %%
model = Sequential()
model.add(Input((None,X_train.shape[1])))
model.add(layers.Dense(24,kernel_initializer='normal',activation='relu'))
model.add(layers.Dense(32,kernel_initializer='normal',activation='relu'))
model.add(layers.Dense(24,kernel_initializer='normal',activation='relu'))
model.add(layers.Dense(1, kernel_initializer='normal',activation='linear'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[R_squared])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, None, 24)          264
#
#  dense_1 (Dense)             (None, None, 32)          800
#
#  dense_2 (Dense)             (None, None, 24)          792
#
#  dense_3 (Dense)             (None, None, 1)           25
#
# =================================================================
# Total params: 1,881
# Trainable params: 1,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
network = model.fit(X_train, y_train, epochs=500,validation_data=(X_test, y_test), workers=-1,batch_size=100,verbose=2)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 158/158 - 3s - loss: 0.9167 - R_squared: 0.0710 - val_loss: 0.9167 - val_R_squared: 0.1305 - 3s/epoch - 17ms/step
# Epoch 2/500
# 158/158 - 0s - loss: 0.8621 - R_squared: 0.1322 - val_loss: 0.8991 - val_R_squared: 0.1449 - 162ms/epoch - 1ms/step
# Epoch 3/500
# 158/158 - 0s - loss: 0.8474 - R_squared: 0.1395 - val_loss: 0.8954 - val_R_squared: 0.1505 - 165ms/epoch - 1ms/step
# Epoch 4/500
# 158/158 - 0s - loss: 0.8348 - R_squared: 0.1519 - val_loss: 0.8846 - val_R_squared: 0.1589 - 158ms/epoch - 998us/step
# Epoch 5/500
# 158/158 - 0s - loss: 0.8246 - R_squared: 0.1709 - val_loss: 0.8814 - val_R_squared: 0.1639 - 152ms/epoch - 964us/step
# Epoch 6/500
# 158/158 - 0s - loss: 0.8102 - R_squared: 0.1832 - val_loss: 0.8746 - val_R_squared: 0.1681 - 167ms/epoch - 1ms/step
# Epoch 7/500
# 158/158 - 0s - loss: 0.7997 - R_squared: 0.1845 - val_loss: 0.8573 - val_R_squared: 0.1855 - 168ms/epoch - 1ms/step
# Epoch 8/500
# 158/158 - 0s - loss: 0.7908 - R_squared: 0.2006 - val_loss: 0.8448 - val_R_squared: 0.1973 - 158ms/epoch - 1000us/step
# Epoch 9/500
# 158/158 - 0s - loss: 0.7779 - R_squared: 0.2122 - val_loss: 0.8279 - val_R_squared: 0.2125 - 166ms/epoch - 1ms/step
# Epoch 10/500
# 158/158 - 0s - loss: 0.7666 - R_squared: 0.2179 - val_loss: 0.8285 - val_R_squared: 0.2098 - 161ms/epoch - 1ms/step
# Epoch 11/500
# 158/158 - 0s - loss: 0.7579 - R_squared: 0.2180 - val_loss: 0.8075 - val_R_squared: 0.2358 - 167ms/epoch - 1ms/step
# Epoch 12/500
# 158/158 - 0s - loss: 0.7457 - R_squared: 0.2438 - val_loss: 0.7969 - val_R_squared: 0.2392 - 166ms/epoch - 1ms/step
# Epoch 13/500
# 158/158 - 0s - loss: 0.7386 - R_squared: 0.2498 - val_loss: 0.8003 - val_R_squared: 0.2348 - 160ms/epoch - 1ms/step
# Epoch 14/500
# 158/158 - 0s - loss: 0.7330 - R_squared: 0.2541 - val_loss: 0.7810 - val_R_squared: 0.2550 - 165ms/epoch - 1ms/step
# Epoch 15/500
# 158/158 - 0s - loss: 0.7229 - R_squared: 0.2610 - val_loss: 0.7909 - val_R_squared: 0.2361 - 161ms/epoch - 1ms/step
# Epoch 16/500
# 158/158 - 0s - loss: 0.7161 - R_squared: 0.2685 - val_loss: 0.8082 - val_R_squared: 0.2151 - 173ms/epoch - 1ms/step
# Epoch 17/500
# 158/158 - 0s - loss: 0.7129 - R_squared: 0.2598 - val_loss: 0.7594 - val_R_squared: 0.2731 - 159ms/epoch - 1ms/step
# Epoch 18/500
# 158/158 - 0s - loss: 0.7072 - R_squared: 0.2724 - val_loss: 0.7801 - val_R_squared: 0.2535 - 168ms/epoch - 1ms/step
# Epoch 19/500
# 158/158 - 0s - loss: 0.6988 - R_squared: 0.2868 - val_loss: 0.7748 - val_R_squared: 0.2508 - 161ms/epoch - 1ms/step
# Epoch 20/500
# 158/158 - 0s - loss: 0.7006 - R_squared: 0.2839 - val_loss: 0.7726 - val_R_squared: 0.2539 - 169ms/epoch - 1ms/step
# Epoch 21/500
# 158/158 - 0s - loss: 0.6914 - R_squared: 0.2822 - val_loss: 0.7692 - val_R_squared: 0.2648 - 164ms/epoch - 1ms/step
# Epoch 22/500
# 158/158 - 0s - loss: 0.6874 - R_squared: 0.2923 - val_loss: 0.7511 - val_R_squared: 0.2796 - 168ms/epoch - 1ms/step
# Epoch 23/500
# 158/158 - 0s - loss: 0.6885 - R_squared: 0.2939 - val_loss: 0.7591 - val_R_squared: 0.2692 - 164ms/epoch - 1ms/step
# Epoch 24/500
# 158/158 - 0s - loss: 0.6851 - R_squared: 0.2990 - val_loss: 0.7675 - val_R_squared: 0.2658 - 153ms/epoch - 967us/step
# Epoch 25/500
# 158/158 - 0s - loss: 0.6782 - R_squared: 0.3065 - val_loss: 0.7457 - val_R_squared: 0.2837 - 167ms/epoch - 1ms/step
# Epoch 26/500
# 158/158 - 0s - loss: 0.6742 - R_squared: 0.3055 - val_loss: 0.7516 - val_R_squared: 0.2766 - 161ms/epoch - 1ms/step
# Epoch 27/500
# 158/158 - 0s - loss: 0.6743 - R_squared: 0.3010 - val_loss: 0.7420 - val_R_squared: 0.2855 - 167ms/epoch - 1ms/step
# Epoch 28/500
# 158/158 - 0s - loss: 0.6724 - R_squared: 0.3138 - val_loss: 0.7518 - val_R_squared: 0.2813 - 163ms/epoch - 1ms/step
# Epoch 29/500
# 158/158 - 0s - loss: 0.6659 - R_squared: 0.3198 - val_loss: 0.7459 - val_R_squared: 0.2849 - 148ms/epoch - 937us/step
# Epoch 30/500
# 158/158 - 0s - loss: 0.6677 - R_squared: 0.3120 - val_loss: 0.7327 - val_R_squared: 0.2990 - 149ms/epoch - 944us/step
# Epoch 31/500
# 158/158 - 0s - loss: 0.6648 - R_squared: 0.3018 - val_loss: 0.7455 - val_R_squared: 0.2866 - 163ms/epoch - 1ms/step
# Epoch 32/500
# 158/158 - 0s - loss: 0.6631 - R_squared: 0.3211 - val_loss: 0.7433 - val_R_squared: 0.2860 - 166ms/epoch - 1ms/step
# Epoch 33/500
# 158/158 - 0s - loss: 0.6594 - R_squared: 0.3230 - val_loss: 0.7441 - val_R_squared: 0.2826 - 168ms/epoch - 1ms/step
# Epoch 34/500
# 158/158 - 0s - loss: 0.6571 - R_squared: 0.3254 - val_loss: 0.7608 - val_R_squared: 0.2613 - 166ms/epoch - 1ms/step
# Epoch 35/500
# 158/158 - 0s - loss: 0.6570 - R_squared: 0.3186 - val_loss: 0.7491 - val_R_squared: 0.2813 - 154ms/epoch - 976us/step
# Epoch 36/500
# 158/158 - 0s - loss: 0.6556 - R_squared: 0.3227 - val_loss: 0.7520 - val_R_squared: 0.2757 - 165ms/epoch - 1ms/step
# Epoch 37/500
# 158/158 - 0s - loss: 0.6497 - R_squared: 0.3366 - val_loss: 0.7516 - val_R_squared: 0.2677 - 167ms/epoch - 1ms/step
# Epoch 38/500
# 158/158 - 0s - loss: 0.6515 - R_squared: 0.3352 - val_loss: 0.7266 - val_R_squared: 0.3019 - 154ms/epoch - 977us/step
# Epoch 39/500
# 158/158 - 0s - loss: 0.6536 - R_squared: 0.3202 - val_loss: 0.7396 - val_R_squared: 0.2914 - 163ms/epoch - 1ms/step
# Epoch 40/500
# 158/158 - 0s - loss: 0.6468 - R_squared: 0.3339 - val_loss: 0.7270 - val_R_squared: 0.3047 - 161ms/epoch - 1ms/step
# Epoch 41/500
# 158/158 - 0s - loss: 0.6476 - R_squared: 0.3335 - val_loss: 0.7358 - val_R_squared: 0.2917 - 172ms/epoch - 1ms/step
# Epoch 42/500
# 158/158 - 0s - loss: 0.6386 - R_squared: 0.3259 - val_loss: 0.7141 - val_R_squared: 0.3119 - 146ms/epoch - 923us/step
# Epoch 43/500
# 158/158 - 0s - loss: 0.6443 - R_squared: 0.3353 - val_loss: 0.7377 - val_R_squared: 0.2946 - 149ms/epoch - 945us/step
# Epoch 44/500
# 158/158 - 0s - loss: 0.6412 - R_squared: 0.3372 - val_loss: 0.7354 - val_R_squared: 0.2927 - 161ms/epoch - 1ms/step
# Epoch 45/500
# 158/158 - 0s - loss: 0.6403 - R_squared: 0.3377 - val_loss: 0.7228 - val_R_squared: 0.3078 - 167ms/epoch - 1ms/step
# Epoch 46/500
# 158/158 - 0s - loss: 0.6386 - R_squared: 0.3363 - val_loss: 0.7623 - val_R_squared: 0.2727 - 146ms/epoch - 922us/step
# Epoch 47/500
# 158/158 - 0s - loss: 0.6413 - R_squared: 0.3402 - val_loss: 0.7213 - val_R_squared: 0.3079 - 147ms/epoch - 933us/step
# Epoch 48/500
# 158/158 - 0s - loss: 0.6346 - R_squared: 0.3394 - val_loss: 0.7270 - val_R_squared: 0.2992 - 165ms/epoch - 1ms/step
# Epoch 49/500
# 158/158 - 0s - loss: 0.6318 - R_squared: 0.3499 - val_loss: 0.7309 - val_R_squared: 0.3005 - 165ms/epoch - 1ms/step
# Epoch 50/500
# 158/158 - 0s - loss: 0.6333 - R_squared: 0.3486 - val_loss: 0.7247 - val_R_squared: 0.3047 - 145ms/epoch - 917us/step
# Epoch 51/500
# 158/158 - 0s - loss: 0.6363 - R_squared: 0.3487 - val_loss: 0.7135 - val_R_squared: 0.3173 - 157ms/epoch - 993us/step
# Epoch 52/500
# 158/158 - 0s - loss: 0.6307 - R_squared: 0.3538 - val_loss: 0.7237 - val_R_squared: 0.3038 - 163ms/epoch - 1ms/step
# Epoch 53/500
# 158/158 - 0s - loss: 0.6295 - R_squared: 0.3443 - val_loss: 0.7134 - val_R_squared: 0.3122 - 156ms/epoch - 989us/step
# Epoch 54/500
# 158/158 - 0s - loss: 0.6260 - R_squared: 0.3591 - val_loss: 0.7148 - val_R_squared: 0.3084 - 161ms/epoch - 1ms/step
# Epoch 55/500
# 158/158 - 0s - loss: 0.6281 - R_squared: 0.3521 - val_loss: 0.7074 - val_R_squared: 0.3186 - 168ms/epoch - 1ms/step
# Epoch 56/500
# 158/158 - 0s - loss: 0.6231 - R_squared: 0.3604 - val_loss: 0.7216 - val_R_squared: 0.3046 - 151ms/epoch - 958us/step
# Epoch 57/500
# 158/158 - 0s - loss: 0.6235 - R_squared: 0.3397 - val_loss: 0.7498 - val_R_squared: 0.2698 - 179ms/epoch - 1ms/step
# Epoch 58/500
# 158/158 - 0s - loss: 0.6279 - R_squared: 0.3424 - val_loss: 0.7109 - val_R_squared: 0.3184 - 151ms/epoch - 953us/step
# Epoch 59/500
# 158/158 - 0s - loss: 0.6220 - R_squared: 0.3509 - val_loss: 0.7245 - val_R_squared: 0.3036 - 163ms/epoch - 1ms/step
# Epoch 60/500
# 158/158 - 0s - loss: 0.6163 - R_squared: 0.3568 - val_loss: 0.7189 - val_R_squared: 0.3069 - 162ms/epoch - 1ms/step
# Epoch 61/500
# 158/158 - 0s - loss: 0.6179 - R_squared: 0.3581 - val_loss: 0.7378 - val_R_squared: 0.2807 - 165ms/epoch - 1ms/step
# Epoch 62/500
# 158/158 - 0s - loss: 0.6202 - R_squared: 0.3554 - val_loss: 0.7065 - val_R_squared: 0.3234 - 161ms/epoch - 1ms/step
# Epoch 63/500
# 158/158 - 0s - loss: 0.6160 - R_squared: 0.3622 - val_loss: 0.7113 - val_R_squared: 0.3191 - 155ms/epoch - 978us/step
# Epoch 64/500
# 158/158 - 0s - loss: 0.6213 - R_squared: 0.3537 - val_loss: 0.7456 - val_R_squared: 0.2727 - 164ms/epoch - 1ms/step
# Epoch 65/500
# 158/158 - 0s - loss: 0.6188 - R_squared: 0.3570 - val_loss: 0.7374 - val_R_squared: 0.2995 - 165ms/epoch - 1ms/step
# Epoch 66/500
# 158/158 - 0s - loss: 0.6157 - R_squared: 0.3602 - val_loss: 0.7506 - val_R_squared: 0.2620 - 161ms/epoch - 1ms/step
# Epoch 67/500
# 158/158 - 0s - loss: 0.6159 - R_squared: 0.3602 - val_loss: 0.6993 - val_R_squared: 0.3315 - 156ms/epoch - 987us/step
# Epoch 68/500
# 158/158 - 0s - loss: 0.6077 - R_squared: 0.3657 - val_loss: 0.7247 - val_R_squared: 0.3012 - 251ms/epoch - 2ms/step
# Epoch 69/500
# 158/158 - 0s - loss: 0.6125 - R_squared: 0.3580 - val_loss: 0.7002 - val_R_squared: 0.3310 - 150ms/epoch - 950us/step
# Epoch 70/500
# 158/158 - 0s - loss: 0.6166 - R_squared: 0.3422 - val_loss: 0.6991 - val_R_squared: 0.3263 - 164ms/epoch - 1ms/step
# Epoch 71/500
# 158/158 - 0s - loss: 0.6076 - R_squared: 0.3583 - val_loss: 0.7073 - val_R_squared: 0.3256 - 161ms/epoch - 1ms/step
# Epoch 72/500
# 158/158 - 0s - loss: 0.6011 - R_squared: 0.3770 - val_loss: 0.7005 - val_R_squared: 0.3233 - 165ms/epoch - 1ms/step
# Epoch 73/500
# 158/158 - 0s - loss: 0.6019 - R_squared: 0.3748 - val_loss: 0.7115 - val_R_squared: 0.3141 - 167ms/epoch - 1ms/step
# Epoch 74/500
# 158/158 - 0s - loss: 0.6099 - R_squared: 0.3672 - val_loss: 0.7122 - val_R_squared: 0.3161 - 153ms/epoch - 971us/step
# Epoch 75/500
# 158/158 - 0s - loss: 0.6015 - R_squared: 0.3776 - val_loss: 0.6966 - val_R_squared: 0.3307 - 188ms/epoch - 1ms/step
# Epoch 76/500
# 158/158 - 0s - loss: 0.6058 - R_squared: 0.3797 - val_loss: 0.7308 - val_R_squared: 0.2933 - 212ms/epoch - 1ms/step
# Epoch 77/500
# 158/158 - 0s - loss: 0.6033 - R_squared: 0.3766 - val_loss: 0.7360 - val_R_squared: 0.2828 - 188ms/epoch - 1ms/step
# Epoch 78/500
# 158/158 - 0s - loss: 0.6006 - R_squared: 0.3845 - val_loss: 0.7053 - val_R_squared: 0.3221 - 196ms/epoch - 1ms/step
# Epoch 79/500
# 158/158 - 0s - loss: 0.6011 - R_squared: 0.3824 - val_loss: 0.7182 - val_R_squared: 0.3135 - 147ms/epoch - 932us/step
# Epoch 80/500
# 158/158 - 0s - loss: 0.5975 - R_squared: 0.3828 - val_loss: 0.7169 - val_R_squared: 0.3044 - 178ms/epoch - 1ms/step
# Epoch 81/500
# 158/158 - 0s - loss: 0.5998 - R_squared: 0.3783 - val_loss: 0.7163 - val_R_squared: 0.3074 - 163ms/epoch - 1ms/step
# Epoch 82/500
# 158/158 - 0s - loss: 0.5990 - R_squared: 0.3747 - val_loss: 0.7237 - val_R_squared: 0.3111 - 156ms/epoch - 987us/step
# Epoch 83/500
# 158/158 - 0s - loss: 0.5961 - R_squared: 0.3816 - val_loss: 0.7087 - val_R_squared: 0.3109 - 162ms/epoch - 1ms/step
# Epoch 84/500
# 158/158 - 0s - loss: 0.5942 - R_squared: 0.3886 - val_loss: 0.6854 - val_R_squared: 0.3426 - 158ms/epoch - 1ms/step
# Epoch 85/500
# 158/158 - 0s - loss: 0.5901 - R_squared: 0.3922 - val_loss: 0.7212 - val_R_squared: 0.3077 - 182ms/epoch - 1ms/step
# Epoch 86/500
# 158/158 - 0s - loss: 0.5966 - R_squared: 0.3770 - val_loss: 0.6805 - val_R_squared: 0.3530 - 158ms/epoch - 1000us/step
# Epoch 87/500
# 158/158 - 0s - loss: 0.5928 - R_squared: 0.3879 - val_loss: 0.7174 - val_R_squared: 0.3001 - 168ms/epoch - 1ms/step
# Epoch 88/500
# 158/158 - 0s - loss: 0.5905 - R_squared: 0.3773 - val_loss: 0.6800 - val_R_squared: 0.3512 - 158ms/epoch - 1ms/step
# Epoch 89/500
# 158/158 - 0s - loss: 0.5952 - R_squared: 0.3749 - val_loss: 0.6860 - val_R_squared: 0.3445 - 151ms/epoch - 957us/step
# Epoch 90/500
# 158/158 - 0s - loss: 0.5920 - R_squared: 0.3886 - val_loss: 0.6930 - val_R_squared: 0.3326 - 161ms/epoch - 1ms/step
# Epoch 91/500
# 158/158 - 0s - loss: 0.5845 - R_squared: 0.3903 - val_loss: 0.6899 - val_R_squared: 0.3403 - 167ms/epoch - 1ms/step
# Epoch 92/500
# 158/158 - 0s - loss: 0.5833 - R_squared: 0.3873 - val_loss: 0.6912 - val_R_squared: 0.3381 - 161ms/epoch - 1ms/step
# Epoch 93/500
# 158/158 - 0s - loss: 0.5878 - R_squared: 0.3902 - val_loss: 0.7093 - val_R_squared: 0.3135 - 165ms/epoch - 1ms/step
# Epoch 94/500
# 158/158 - 0s - loss: 0.5841 - R_squared: 0.3864 - val_loss: 0.7145 - val_R_squared: 0.3214 - 170ms/epoch - 1ms/step
# Epoch 95/500
# 158/158 - 0s - loss: 0.5892 - R_squared: 0.3870 - val_loss: 0.6812 - val_R_squared: 0.3510 - 158ms/epoch - 1000us/step
# Epoch 96/500
# 158/158 - 0s - loss: 0.5823 - R_squared: 0.3945 - val_loss: 0.7035 - val_R_squared: 0.3349 - 165ms/epoch - 1ms/step
# Epoch 97/500
# 158/158 - 0s - loss: 0.5862 - R_squared: 0.3841 - val_loss: 0.7152 - val_R_squared: 0.3015 - 167ms/epoch - 1ms/step
# Epoch 98/500
# 158/158 - 0s - loss: 0.5798 - R_squared: 0.4011 - val_loss: 0.6822 - val_R_squared: 0.3436 - 168ms/epoch - 1ms/step
# Epoch 99/500
# 158/158 - 0s - loss: 0.5814 - R_squared: 0.3962 - val_loss: 0.6668 - val_R_squared: 0.3600 - 158ms/epoch - 1000us/step
# Epoch 100/500
# 158/158 - 0s - loss: 0.5763 - R_squared: 0.4032 - val_loss: 0.6787 - val_R_squared: 0.3501 - 167ms/epoch - 1ms/step
# Epoch 101/500
# 158/158 - 0s - loss: 0.5814 - R_squared: 0.3995 - val_loss: 0.6787 - val_R_squared: 0.3527 - 146ms/epoch - 924us/step
# Epoch 102/500
# 158/158 - 0s - loss: 0.5812 - R_squared: 0.3965 - val_loss: 0.6733 - val_R_squared: 0.3538 - 165ms/epoch - 1ms/step
# Epoch 103/500
# 158/158 - 0s - loss: 0.5739 - R_squared: 0.4099 - val_loss: 0.6812 - val_R_squared: 0.3498 - 168ms/epoch - 1ms/step
# Epoch 104/500
# 158/158 - 0s - loss: 0.5753 - R_squared: 0.3940 - val_loss: 0.7046 - val_R_squared: 0.3162 - 164ms/epoch - 1ms/step
# Epoch 105/500
# 158/158 - 0s - loss: 0.5743 - R_squared: 0.4094 - val_loss: 0.6792 - val_R_squared: 0.3486 - 162ms/epoch - 1ms/step
# Epoch 106/500
# 158/158 - 0s - loss: 0.5720 - R_squared: 0.4090 - val_loss: 0.6817 - val_R_squared: 0.3445 - 170ms/epoch - 1ms/step
# Epoch 107/500
# 158/158 - 0s - loss: 0.5693 - R_squared: 0.4063 - val_loss: 0.7065 - val_R_squared: 0.3285 - 163ms/epoch - 1ms/step
# Epoch 108/500
# 158/158 - 0s - loss: 0.5665 - R_squared: 0.4070 - val_loss: 0.6987 - val_R_squared: 0.3347 - 158ms/epoch - 1000us/step
# Epoch 109/500
# 158/158 - 0s - loss: 0.5724 - R_squared: 0.4076 - val_loss: 0.6896 - val_R_squared: 0.3406 - 167ms/epoch - 1ms/step
# Epoch 110/500
# 158/158 - 0s - loss: 0.5720 - R_squared: 0.4046 - val_loss: 0.6722 - val_R_squared: 0.3583 - 158ms/epoch - 1000us/step
# Epoch 111/500
# 158/158 - 0s - loss: 0.5659 - R_squared: 0.4117 - val_loss: 0.6823 - val_R_squared: 0.3418 - 161ms/epoch - 1ms/step
# Epoch 112/500
# 158/158 - 0s - loss: 0.5708 - R_squared: 0.4072 - val_loss: 0.6994 - val_R_squared: 0.3270 - 162ms/epoch - 1ms/step
# Epoch 113/500
# 158/158 - 0s - loss: 0.5664 - R_squared: 0.4133 - val_loss: 0.7028 - val_R_squared: 0.3248 - 157ms/epoch - 992us/step
# Epoch 114/500
# 158/158 - 0s - loss: 0.5648 - R_squared: 0.4079 - val_loss: 0.6757 - val_R_squared: 0.3471 - 174ms/epoch - 1ms/step
# Epoch 115/500
# 158/158 - 0s - loss: 0.5684 - R_squared: 0.4025 - val_loss: 0.6637 - val_R_squared: 0.3679 - 167ms/epoch - 1ms/step
# Epoch 116/500
# 158/158 - 0s - loss: 0.5591 - R_squared: 0.4173 - val_loss: 0.6932 - val_R_squared: 0.3283 - 158ms/epoch - 1ms/step
# Epoch 117/500
# 158/158 - 0s - loss: 0.5696 - R_squared: 0.4075 - val_loss: 0.7242 - val_R_squared: 0.3130 - 167ms/epoch - 1ms/step
# Epoch 118/500
# 158/158 - 0s - loss: 0.5621 - R_squared: 0.4108 - val_loss: 0.6910 - val_R_squared: 0.3382 - 161ms/epoch - 1ms/step
# Epoch 119/500
# 158/158 - 0s - loss: 0.5651 - R_squared: 0.4130 - val_loss: 0.6715 - val_R_squared: 0.3553 - 165ms/epoch - 1ms/step
# Epoch 120/500
# 158/158 - 0s - loss: 0.5636 - R_squared: 0.4167 - val_loss: 0.6930 - val_R_squared: 0.3301 - 168ms/epoch - 1ms/step
# Epoch 121/500
# 158/158 - 0s - loss: 0.5561 - R_squared: 0.4225 - val_loss: 0.6726 - val_R_squared: 0.3493 - 165ms/epoch - 1ms/step
# Epoch 122/500
# 158/158 - 0s - loss: 0.5588 - R_squared: 0.4052 - val_loss: 0.6726 - val_R_squared: 0.3586 - 154ms/epoch - 976us/step
# Epoch 123/500
# 158/158 - 0s - loss: 0.5543 - R_squared: 0.4158 - val_loss: 0.6685 - val_R_squared: 0.3621 - 157ms/epoch - 991us/step
# Epoch 124/500
# 158/158 - 0s - loss: 0.5586 - R_squared: 0.4172 - val_loss: 0.6742 - val_R_squared: 0.3443 - 169ms/epoch - 1ms/step
# Epoch 125/500
# 158/158 - 0s - loss: 0.5652 - R_squared: 0.4118 - val_loss: 0.6768 - val_R_squared: 0.3579 - 158ms/epoch - 998us/step
# Epoch 126/500
# 158/158 - 0s - loss: 0.5626 - R_squared: 0.4169 - val_loss: 0.6968 - val_R_squared: 0.3396 - 166ms/epoch - 1ms/step
# Epoch 127/500
# 158/158 - 0s - loss: 0.5582 - R_squared: 0.4282 - val_loss: 0.6588 - val_R_squared: 0.3690 - 167ms/epoch - 1ms/step
# Epoch 128/500
# 158/158 - 0s - loss: 0.5551 - R_squared: 0.4170 - val_loss: 0.6754 - val_R_squared: 0.3468 - 168ms/epoch - 1ms/step
# Epoch 129/500
# 158/158 - 0s - loss: 0.5630 - R_squared: 0.4013 - val_loss: 0.6855 - val_R_squared: 0.3451 - 165ms/epoch - 1ms/step
# Epoch 130/500
# 158/158 - 0s - loss: 0.5568 - R_squared: 0.4196 - val_loss: 0.6995 - val_R_squared: 0.3190 - 168ms/epoch - 1ms/step
# Epoch 131/500
# 158/158 - 0s - loss: 0.5548 - R_squared: 0.4163 - val_loss: 0.6685 - val_R_squared: 0.3614 - 174ms/epoch - 1ms/step
# Epoch 132/500
# 158/158 - 0s - loss: 0.5444 - R_squared: 0.4224 - val_loss: 0.6642 - val_R_squared: 0.3623 - 169ms/epoch - 1ms/step
# Epoch 133/500
# 158/158 - 0s - loss: 0.5454 - R_squared: 0.4317 - val_loss: 0.7314 - val_R_squared: 0.2895 - 171ms/epoch - 1ms/step
# Epoch 134/500
# 158/158 - 0s - loss: 0.5572 - R_squared: 0.4215 - val_loss: 0.6892 - val_R_squared: 0.3282 - 172ms/epoch - 1ms/step
# Epoch 135/500
# 158/158 - 0s - loss: 0.5586 - R_squared: 0.4090 - val_loss: 0.6803 - val_R_squared: 0.3434 - 172ms/epoch - 1ms/step
# Epoch 136/500
# 158/158 - 0s - loss: 0.5566 - R_squared: 0.4123 - val_loss: 0.6699 - val_R_squared: 0.3555 - 173ms/epoch - 1ms/step
# Epoch 137/500
# 158/158 - 0s - loss: 0.5516 - R_squared: 0.4274 - val_loss: 0.6619 - val_R_squared: 0.3649 - 173ms/epoch - 1ms/step
# Epoch 138/500
# 158/158 - 0s - loss: 0.5438 - R_squared: 0.4275 - val_loss: 0.6726 - val_R_squared: 0.3549 - 155ms/epoch - 978us/step
# Epoch 139/500
# 158/158 - 0s - loss: 0.5510 - R_squared: 0.4248 - val_loss: 0.6833 - val_R_squared: 0.3384 - 188ms/epoch - 1ms/step
# Epoch 140/500
# 158/158 - 0s - loss: 0.5435 - R_squared: 0.4414 - val_loss: 0.6749 - val_R_squared: 0.3605 - 163ms/epoch - 1ms/step
# Epoch 141/500
# 158/158 - 0s - loss: 0.5438 - R_squared: 0.4185 - val_loss: 0.6791 - val_R_squared: 0.3456 - 197ms/epoch - 1ms/step
# Epoch 142/500
# 158/158 - 0s - loss: 0.5475 - R_squared: 0.4209 - val_loss: 0.6636 - val_R_squared: 0.3568 - 191ms/epoch - 1ms/step
# Epoch 143/500
# 158/158 - 0s - loss: 0.5426 - R_squared: 0.4407 - val_loss: 0.6595 - val_R_squared: 0.3617 - 155ms/epoch - 982us/step
# Epoch 144/500
# 158/158 - 0s - loss: 0.5467 - R_squared: 0.4150 - val_loss: 0.6699 - val_R_squared: 0.3576 - 161ms/epoch - 1ms/step
# Epoch 145/500
# 158/158 - 0s - loss: 0.5425 - R_squared: 0.4212 - val_loss: 0.6638 - val_R_squared: 0.3586 - 165ms/epoch - 1ms/step
# Epoch 146/500
# 158/158 - 0s - loss: 0.5395 - R_squared: 0.4358 - val_loss: 0.6671 - val_R_squared: 0.3630 - 180ms/epoch - 1ms/step
# Epoch 147/500
# 158/158 - 0s - loss: 0.5449 - R_squared: 0.4310 - val_loss: 0.6888 - val_R_squared: 0.3336 - 179ms/epoch - 1ms/step
# Epoch 148/500
# 158/158 - 0s - loss: 0.5438 - R_squared: 0.4326 - val_loss: 0.6744 - val_R_squared: 0.3546 - 183ms/epoch - 1ms/step
# Epoch 149/500
# 158/158 - 0s - loss: 0.5442 - R_squared: 0.4287 - val_loss: 0.6574 - val_R_squared: 0.3667 - 175ms/epoch - 1ms/step
# Epoch 150/500
# 158/158 - 0s - loss: 0.5437 - R_squared: 0.4299 - val_loss: 0.6901 - val_R_squared: 0.3428 - 174ms/epoch - 1ms/step
# Epoch 151/500
# 158/158 - 0s - loss: 0.5409 - R_squared: 0.4306 - val_loss: 0.6735 - val_R_squared: 0.3627 - 174ms/epoch - 1ms/step
# Epoch 152/500
# 158/158 - 0s - loss: 0.5374 - R_squared: 0.4370 - val_loss: 0.6593 - val_R_squared: 0.3687 - 177ms/epoch - 1ms/step
# Epoch 153/500
# 158/158 - 0s - loss: 0.5411 - R_squared: 0.4267 - val_loss: 0.6871 - val_R_squared: 0.3315 - 172ms/epoch - 1ms/step
# Epoch 154/500
# 158/158 - 0s - loss: 0.5426 - R_squared: 0.4275 - val_loss: 0.6668 - val_R_squared: 0.3659 - 177ms/epoch - 1ms/step
# Epoch 155/500
# 158/158 - 0s - loss: 0.5392 - R_squared: 0.4350 - val_loss: 0.6752 - val_R_squared: 0.3559 - 180ms/epoch - 1ms/step
# Epoch 156/500
# 158/158 - 0s - loss: 0.5378 - R_squared: 0.4304 - val_loss: 0.7029 - val_R_squared: 0.3350 - 216ms/epoch - 1ms/step
# Epoch 157/500
# 158/158 - 0s - loss: 0.5408 - R_squared: 0.4410 - val_loss: 0.6716 - val_R_squared: 0.3495 - 190ms/epoch - 1ms/step
# Epoch 158/500
# 158/158 - 0s - loss: 0.5360 - R_squared: 0.4438 - val_loss: 0.6592 - val_R_squared: 0.3669 - 228ms/epoch - 1ms/step
# Epoch 159/500
# 158/158 - 0s - loss: 0.5269 - R_squared: 0.4459 - val_loss: 0.6977 - val_R_squared: 0.3331 - 166ms/epoch - 1ms/step
# Epoch 160/500
# 158/158 - 0s - loss: 0.5325 - R_squared: 0.4462 - val_loss: 0.7113 - val_R_squared: 0.2983 - 165ms/epoch - 1ms/step
# Epoch 161/500
# 158/158 - 0s - loss: 0.5366 - R_squared: 0.4414 - val_loss: 0.6692 - val_R_squared: 0.3568 - 164ms/epoch - 1ms/step
# Epoch 162/500
# 158/158 - 0s - loss: 0.5339 - R_squared: 0.4416 - val_loss: 0.6657 - val_R_squared: 0.3614 - 157ms/epoch - 994us/step
# Epoch 163/500
# 158/158 - 0s - loss: 0.5331 - R_squared: 0.4346 - val_loss: 0.6450 - val_R_squared: 0.3792 - 160ms/epoch - 1ms/step
# Epoch 164/500
# 158/158 - 0s - loss: 0.5302 - R_squared: 0.4408 - val_loss: 0.6362 - val_R_squared: 0.3901 - 170ms/epoch - 1ms/step
# Epoch 165/500
# 158/158 - 0s - loss: 0.5306 - R_squared: 0.4476 - val_loss: 0.6488 - val_R_squared: 0.3806 - 159ms/epoch - 1ms/step
# Epoch 166/500
# 158/158 - 0s - loss: 0.5322 - R_squared: 0.4439 - val_loss: 0.6749 - val_R_squared: 0.3538 - 169ms/epoch - 1ms/step
# Epoch 167/500
# 158/158 - 0s - loss: 0.5363 - R_squared: 0.4268 - val_loss: 0.6805 - val_R_squared: 0.3400 - 156ms/epoch - 988us/step
# Epoch 168/500
# 158/158 - 0s - loss: 0.5245 - R_squared: 0.4456 - val_loss: 0.6790 - val_R_squared: 0.3544 - 204ms/epoch - 1ms/step
# Epoch 169/500
# 158/158 - 0s - loss: 0.5348 - R_squared: 0.4429 - val_loss: 0.6508 - val_R_squared: 0.3821 - 261ms/epoch - 2ms/step
# Epoch 170/500
# 158/158 - 0s - loss: 0.5255 - R_squared: 0.4457 - val_loss: 0.6785 - val_R_squared: 0.3579 - 260ms/epoch - 2ms/step
# Epoch 171/500
# 158/158 - 0s - loss: 0.5275 - R_squared: 0.4426 - val_loss: 0.6695 - val_R_squared: 0.3637 - 211ms/epoch - 1ms/step
# Epoch 172/500
# 158/158 - 0s - loss: 0.5336 - R_squared: 0.4342 - val_loss: 0.6458 - val_R_squared: 0.3813 - 183ms/epoch - 1ms/step
# Epoch 173/500
# 158/158 - 0s - loss: 0.5310 - R_squared: 0.4353 - val_loss: 0.6678 - val_R_squared: 0.3589 - 166ms/epoch - 1ms/step
# Epoch 174/500
# 158/158 - 0s - loss: 0.5272 - R_squared: 0.4403 - val_loss: 0.6714 - val_R_squared: 0.3446 - 187ms/epoch - 1ms/step
# Epoch 175/500
# 158/158 - 0s - loss: 0.5258 - R_squared: 0.4455 - val_loss: 0.6683 - val_R_squared: 0.3667 - 170ms/epoch - 1ms/step
# Epoch 176/500
# 158/158 - 0s - loss: 0.5239 - R_squared: 0.4468 - val_loss: 0.6982 - val_R_squared: 0.3156 - 176ms/epoch - 1ms/step
# Epoch 177/500
# 158/158 - 0s - loss: 0.5308 - R_squared: 0.4342 - val_loss: 0.6707 - val_R_squared: 0.3597 - 163ms/epoch - 1ms/step
# Epoch 178/500
# 158/158 - 0s - loss: 0.5165 - R_squared: 0.4526 - val_loss: 0.6682 - val_R_squared: 0.3614 - 162ms/epoch - 1ms/step
# Epoch 179/500
# 158/158 - 0s - loss: 0.5270 - R_squared: 0.4477 - val_loss: 0.6907 - val_R_squared: 0.3467 - 145ms/epoch - 916us/step
# Epoch 180/500
# 158/158 - 0s - loss: 0.5223 - R_squared: 0.4491 - val_loss: 0.6798 - val_R_squared: 0.3521 - 156ms/epoch - 989us/step
# Epoch 181/500
# 158/158 - 0s - loss: 0.5215 - R_squared: 0.4533 - val_loss: 0.6591 - val_R_squared: 0.3713 - 156ms/epoch - 989us/step
# Epoch 182/500
# 158/158 - 0s - loss: 0.5184 - R_squared: 0.4453 - val_loss: 0.6766 - val_R_squared: 0.3478 - 156ms/epoch - 989us/step
# Epoch 183/500
# 158/158 - 0s - loss: 0.5290 - R_squared: 0.4430 - val_loss: 0.6447 - val_R_squared: 0.3815 - 156ms/epoch - 989us/step
# Epoch 184/500
# 158/158 - 0s - loss: 0.5185 - R_squared: 0.4516 - val_loss: 0.6555 - val_R_squared: 0.3666 - 170ms/epoch - 1ms/step
# Epoch 185/500
# 158/158 - 0s - loss: 0.5173 - R_squared: 0.4514 - val_loss: 0.6659 - val_R_squared: 0.3575 - 164ms/epoch - 1ms/step
# Epoch 186/500
# 158/158 - 0s - loss: 0.5170 - R_squared: 0.4662 - val_loss: 0.6609 - val_R_squared: 0.3574 - 189ms/epoch - 1ms/step
# Epoch 187/500
# 158/158 - 0s - loss: 0.5100 - R_squared: 0.4614 - val_loss: 0.6808 - val_R_squared: 0.3375 - 238ms/epoch - 2ms/step
# Epoch 188/500
# 158/158 - 0s - loss: 0.5123 - R_squared: 0.4657 - val_loss: 0.6780 - val_R_squared: 0.3522 - 198ms/epoch - 1ms/step
# Epoch 189/500
# 158/158 - 0s - loss: 0.5165 - R_squared: 0.4610 - val_loss: 0.6843 - val_R_squared: 0.3326 - 224ms/epoch - 1ms/step
# Epoch 190/500
# 158/158 - 0s - loss: 0.5209 - R_squared: 0.4607 - val_loss: 0.6754 - val_R_squared: 0.3444 - 233ms/epoch - 1ms/step
# Epoch 191/500
# 158/158 - 0s - loss: 0.5156 - R_squared: 0.4638 - val_loss: 0.6706 - val_R_squared: 0.3499 - 228ms/epoch - 1ms/step
# Epoch 192/500
# 158/158 - 0s - loss: 0.5124 - R_squared: 0.4552 - val_loss: 0.6535 - val_R_squared: 0.3692 - 183ms/epoch - 1ms/step
# Epoch 193/500
# 158/158 - 0s - loss: 0.5176 - R_squared: 0.4609 - val_loss: 0.6720 - val_R_squared: 0.3623 - 235ms/epoch - 1ms/step
# Epoch 194/500
# 158/158 - 0s - loss: 0.5269 - R_squared: 0.4477 - val_loss: 0.6520 - val_R_squared: 0.3664 - 200ms/epoch - 1ms/step
# Epoch 195/500
# 158/158 - 0s - loss: 0.5133 - R_squared: 0.4647 - val_loss: 0.6568 - val_R_squared: 0.3624 - 208ms/epoch - 1ms/step
# Epoch 196/500
# 158/158 - 0s - loss: 0.5067 - R_squared: 0.4735 - val_loss: 0.6658 - val_R_squared: 0.3657 - 185ms/epoch - 1ms/step
# Epoch 197/500
# 158/158 - 0s - loss: 0.5174 - R_squared: 0.4554 - val_loss: 0.6534 - val_R_squared: 0.3701 - 209ms/epoch - 1ms/step
# Epoch 198/500
# 158/158 - 0s - loss: 0.5146 - R_squared: 0.4571 - val_loss: 0.6603 - val_R_squared: 0.3651 - 267ms/epoch - 2ms/step
# Epoch 199/500
# 158/158 - 0s - loss: 0.5051 - R_squared: 0.4750 - val_loss: 0.6536 - val_R_squared: 0.3751 - 413ms/epoch - 3ms/step
# Epoch 200/500
# 158/158 - 0s - loss: 0.5029 - R_squared: 0.4763 - val_loss: 0.6540 - val_R_squared: 0.3616 - 269ms/epoch - 2ms/step
# Epoch 201/500
# 158/158 - 0s - loss: 0.5182 - R_squared: 0.4494 - val_loss: 0.6601 - val_R_squared: 0.3596 - 172ms/epoch - 1ms/step
# Epoch 202/500
# 158/158 - 0s - loss: 0.5022 - R_squared: 0.4622 - val_loss: 0.6401 - val_R_squared: 0.3899 - 157ms/epoch - 996us/step
# Epoch 203/500
# 158/158 - 0s - loss: 0.5169 - R_squared: 0.4491 - val_loss: 0.6397 - val_R_squared: 0.3809 - 179ms/epoch - 1ms/step
# Epoch 204/500
# 158/158 - 0s - loss: 0.5051 - R_squared: 0.4641 - val_loss: 0.7004 - val_R_squared: 0.3137 - 143ms/epoch - 906us/step
# Epoch 205/500
# 158/158 - 0s - loss: 0.5080 - R_squared: 0.4637 - val_loss: 0.6305 - val_R_squared: 0.3917 - 156ms/epoch - 989us/step
# Epoch 206/500
# 158/158 - 0s - loss: 0.4987 - R_squared: 0.4781 - val_loss: 0.6535 - val_R_squared: 0.3756 - 156ms/epoch - 989us/step
# Epoch 207/500
# 158/158 - 0s - loss: 0.5033 - R_squared: 0.4581 - val_loss: 0.6431 - val_R_squared: 0.3816 - 156ms/epoch - 989us/step
# Epoch 208/500
# 158/158 - 0s - loss: 0.5022 - R_squared: 0.4659 - val_loss: 0.6408 - val_R_squared: 0.3823 - 156ms/epoch - 989us/step
# Epoch 209/500
# 158/158 - 0s - loss: 0.5095 - R_squared: 0.4515 - val_loss: 0.6516 - val_R_squared: 0.3827 - 156ms/epoch - 989us/step
# Epoch 210/500
# 158/158 - 0s - loss: 0.5006 - R_squared: 0.4703 - val_loss: 0.6500 - val_R_squared: 0.3738 - 156ms/epoch - 989us/step
# Epoch 211/500
# 158/158 - 0s - loss: 0.5091 - R_squared: 0.4618 - val_loss: 0.6463 - val_R_squared: 0.3758 - 156ms/epoch - 989us/step
# Epoch 212/500
# 158/158 - 0s - loss: 0.5030 - R_squared: 0.4601 - val_loss: 0.6450 - val_R_squared: 0.3809 - 156ms/epoch - 989us/step
# Epoch 213/500
# 158/158 - 0s - loss: 0.5020 - R_squared: 0.4737 - val_loss: 0.7660 - val_R_squared: 0.2418 - 169ms/epoch - 1ms/step
# Epoch 214/500
# 158/158 - 0s - loss: 0.5102 - R_squared: 0.4735 - val_loss: 0.6442 - val_R_squared: 0.3826 - 156ms/epoch - 989us/step
# Epoch 215/500
# 158/158 - 0s - loss: 0.5038 - R_squared: 0.4720 - val_loss: 0.6629 - val_R_squared: 0.3547 - 156ms/epoch - 989us/step
# Epoch 216/500
# 158/158 - 0s - loss: 0.5014 - R_squared: 0.4556 - val_loss: 0.6574 - val_R_squared: 0.3653 - 156ms/epoch - 989us/step
# Epoch 217/500
# 158/158 - 0s - loss: 0.4942 - R_squared: 0.4712 - val_loss: 0.6562 - val_R_squared: 0.3633 - 165ms/epoch - 1ms/step
# Epoch 218/500
# 158/158 - 0s - loss: 0.4975 - R_squared: 0.4819 - val_loss: 0.6459 - val_R_squared: 0.3820 - 179ms/epoch - 1ms/step
# Epoch 219/500
# 158/158 - 0s - loss: 0.5103 - R_squared: 0.4544 - val_loss: 0.6547 - val_R_squared: 0.3611 - 163ms/epoch - 1ms/step
# Epoch 220/500
# 158/158 - 0s - loss: 0.4995 - R_squared: 0.4717 - val_loss: 0.6460 - val_R_squared: 0.3825 - 172ms/epoch - 1ms/step
# Epoch 221/500
# 158/158 - 0s - loss: 0.4984 - R_squared: 0.4788 - val_loss: 0.6617 - val_R_squared: 0.3712 - 156ms/epoch - 989us/step
# Epoch 222/500
# 158/158 - 0s - loss: 0.5002 - R_squared: 0.4712 - val_loss: 0.6580 - val_R_squared: 0.3717 - 156ms/epoch - 989us/step
# Epoch 223/500
# 158/158 - 0s - loss: 0.4961 - R_squared: 0.4755 - val_loss: 0.6489 - val_R_squared: 0.3825 - 201ms/epoch - 1ms/step
# Epoch 224/500
# 158/158 - 0s - loss: 0.4911 - R_squared: 0.4804 - val_loss: 0.6340 - val_R_squared: 0.3907 - 179ms/epoch - 1ms/step
# Epoch 225/500
# 158/158 - 0s - loss: 0.4939 - R_squared: 0.4860 - val_loss: 0.6487 - val_R_squared: 0.3730 - 159ms/epoch - 1ms/step
# Epoch 226/500
# 158/158 - 0s - loss: 0.4967 - R_squared: 0.4684 - val_loss: 0.6411 - val_R_squared: 0.3800 - 172ms/epoch - 1ms/step
# Epoch 227/500
# 158/158 - 0s - loss: 0.5027 - R_squared: 0.4713 - val_loss: 0.6582 - val_R_squared: 0.3640 - 158ms/epoch - 1ms/step
# Epoch 228/500
# 158/158 - 0s - loss: 0.4915 - R_squared: 0.4827 - val_loss: 0.6558 - val_R_squared: 0.3655 - 212ms/epoch - 1ms/step
# Epoch 229/500
# 158/158 - 0s - loss: 0.4972 - R_squared: 0.4744 - val_loss: 0.6596 - val_R_squared: 0.3726 - 188ms/epoch - 1ms/step
# Epoch 230/500
# 158/158 - 0s - loss: 0.4929 - R_squared: 0.4816 - val_loss: 0.6507 - val_R_squared: 0.3801 - 186ms/epoch - 1ms/step
# Epoch 231/500
# 158/158 - 0s - loss: 0.5009 - R_squared: 0.4756 - val_loss: 0.6584 - val_R_squared: 0.3684 - 170ms/epoch - 1ms/step
# Epoch 232/500
# 158/158 - 0s - loss: 0.4932 - R_squared: 0.4708 - val_loss: 0.6417 - val_R_squared: 0.3825 - 173ms/epoch - 1ms/step
# Epoch 233/500
# 158/158 - 0s - loss: 0.4873 - R_squared: 0.4865 - val_loss: 0.7348 - val_R_squared: 0.2706 - 205ms/epoch - 1ms/step
# Epoch 234/500
# 158/158 - 0s - loss: 0.5000 - R_squared: 0.4784 - val_loss: 0.6441 - val_R_squared: 0.3897 - 202ms/epoch - 1ms/step
# Epoch 235/500
# 158/158 - 0s - loss: 0.4968 - R_squared: 0.4749 - val_loss: 0.6409 - val_R_squared: 0.3871 - 187ms/epoch - 1ms/step
# Epoch 236/500
# 158/158 - 0s - loss: 0.4848 - R_squared: 0.4891 - val_loss: 0.6539 - val_R_squared: 0.3732 - 201ms/epoch - 1ms/step
# Epoch 237/500
# 158/158 - 0s - loss: 0.4971 - R_squared: 0.4803 - val_loss: 0.6532 - val_R_squared: 0.3744 - 151ms/epoch - 956us/step
# Epoch 238/500
# 158/158 - 0s - loss: 0.4841 - R_squared: 0.4921 - val_loss: 0.6191 - val_R_squared: 0.4096 - 156ms/epoch - 989us/step
# Epoch 239/500
# 158/158 - 0s - loss: 0.4921 - R_squared: 0.4839 - val_loss: 0.6487 - val_R_squared: 0.3782 - 196ms/epoch - 1ms/step
# Epoch 240/500
# 158/158 - 0s - loss: 0.4889 - R_squared: 0.4728 - val_loss: 0.6424 - val_R_squared: 0.3916 - 165ms/epoch - 1ms/step
# Epoch 241/500
# 158/158 - 0s - loss: 0.4929 - R_squared: 0.4831 - val_loss: 0.6279 - val_R_squared: 0.4044 - 189ms/epoch - 1ms/step
# Epoch 242/500
# 158/158 - 0s - loss: 0.4902 - R_squared: 0.4824 - val_loss: 0.6696 - val_R_squared: 0.3622 - 156ms/epoch - 989us/step
# Epoch 243/500
# 158/158 - 0s - loss: 0.4928 - R_squared: 0.4728 - val_loss: 0.6439 - val_R_squared: 0.3779 - 206ms/epoch - 1ms/step
# Epoch 244/500
# 158/158 - 0s - loss: 0.4849 - R_squared: 0.4796 - val_loss: 0.6354 - val_R_squared: 0.3952 - 173ms/epoch - 1ms/step
# Epoch 245/500
# 158/158 - 0s - loss: 0.4923 - R_squared: 0.4720 - val_loss: 0.6350 - val_R_squared: 0.3909 - 160ms/epoch - 1ms/step
# Epoch 246/500
# 158/158 - 0s - loss: 0.4906 - R_squared: 0.4792 - val_loss: 0.6484 - val_R_squared: 0.3802 - 156ms/epoch - 989us/step
# Epoch 247/500
# 158/158 - 0s - loss: 0.4926 - R_squared: 0.4800 - val_loss: 0.6310 - val_R_squared: 0.3952 - 164ms/epoch - 1ms/step
# Epoch 248/500
# 158/158 - 0s - loss: 0.4833 - R_squared: 0.4851 - val_loss: 0.6353 - val_R_squared: 0.3871 - 177ms/epoch - 1ms/step
# Epoch 249/500
# 158/158 - 0s - loss: 0.4927 - R_squared: 0.4819 - val_loss: 0.6461 - val_R_squared: 0.3830 - 156ms/epoch - 989us/step
# Epoch 250/500
# 158/158 - 0s - loss: 0.4919 - R_squared: 0.4781 - val_loss: 0.6257 - val_R_squared: 0.3999 - 156ms/epoch - 989us/step
# Epoch 251/500
# 158/158 - 0s - loss: 0.4835 - R_squared: 0.4829 - val_loss: 0.6514 - val_R_squared: 0.3680 - 156ms/epoch - 989us/step
# Epoch 252/500
# 158/158 - 0s - loss: 0.4860 - R_squared: 0.4889 - val_loss: 0.6647 - val_R_squared: 0.3566 - 156ms/epoch - 989us/step
# Epoch 253/500
# 158/158 - 0s - loss: 0.4902 - R_squared: 0.4785 - val_loss: 0.6353 - val_R_squared: 0.3848 - 179ms/epoch - 1ms/step
# Epoch 254/500
# 158/158 - 0s - loss: 0.4850 - R_squared: 0.4864 - val_loss: 0.6162 - val_R_squared: 0.4076 - 176ms/epoch - 1ms/step
# Epoch 255/500
# 158/158 - 0s - loss: 0.4862 - R_squared: 0.4791 - val_loss: 0.6519 - val_R_squared: 0.3697 - 182ms/epoch - 1ms/step
# Epoch 256/500
# 158/158 - 0s - loss: 0.4878 - R_squared: 0.4809 - val_loss: 0.6213 - val_R_squared: 0.4040 - 189ms/epoch - 1ms/step
# Epoch 257/500
# 158/158 - 0s - loss: 0.4794 - R_squared: 0.4848 - val_loss: 0.6398 - val_R_squared: 0.3850 - 165ms/epoch - 1ms/step
# Epoch 258/500
# 158/158 - 0s - loss: 0.4819 - R_squared: 0.4866 - val_loss: 0.6261 - val_R_squared: 0.3940 - 208ms/epoch - 1ms/step
# Epoch 259/500
# 158/158 - 0s - loss: 0.4877 - R_squared: 0.4860 - val_loss: 0.6513 - val_R_squared: 0.3733 - 211ms/epoch - 1ms/step
# Epoch 260/500
# 158/158 - 0s - loss: 0.4890 - R_squared: 0.4797 - val_loss: 0.6456 - val_R_squared: 0.3749 - 169ms/epoch - 1ms/step
# Epoch 261/500
# 158/158 - 0s - loss: 0.4819 - R_squared: 0.4896 - val_loss: 0.6422 - val_R_squared: 0.3747 - 152ms/epoch - 961us/step
# Epoch 262/500
# 158/158 - 0s - loss: 0.4772 - R_squared: 0.5033 - val_loss: 0.6401 - val_R_squared: 0.3808 - 172ms/epoch - 1ms/step
# Epoch 263/500
# 158/158 - 0s - loss: 0.4735 - R_squared: 0.4938 - val_loss: 0.7208 - val_R_squared: 0.2873 - 187ms/epoch - 1ms/step
# Epoch 264/500
# 158/158 - 0s - loss: 0.4778 - R_squared: 0.4939 - val_loss: 0.6532 - val_R_squared: 0.3608 - 175ms/epoch - 1ms/step
# Epoch 265/500
# 158/158 - 0s - loss: 0.4738 - R_squared: 0.5035 - val_loss: 0.6456 - val_R_squared: 0.3739 - 158ms/epoch - 998us/step
# Epoch 266/500
# 158/158 - 0s - loss: 0.4840 - R_squared: 0.4844 - val_loss: 0.6418 - val_R_squared: 0.3892 - 156ms/epoch - 989us/step
# Epoch 267/500
# 158/158 - 0s - loss: 0.4812 - R_squared: 0.4979 - val_loss: 0.6324 - val_R_squared: 0.3947 - 156ms/epoch - 989us/step
# Epoch 268/500
# 158/158 - 0s - loss: 0.4803 - R_squared: 0.4797 - val_loss: 0.6876 - val_R_squared: 0.3272 - 170ms/epoch - 1ms/step
# Epoch 269/500
# 158/158 - 0s - loss: 0.4897 - R_squared: 0.4753 - val_loss: 0.6533 - val_R_squared: 0.3630 - 197ms/epoch - 1ms/step
# Epoch 270/500
# 158/158 - 0s - loss: 0.4853 - R_squared: 0.4815 - val_loss: 0.6637 - val_R_squared: 0.3609 - 202ms/epoch - 1ms/step
# Epoch 271/500
# 158/158 - 0s - loss: 0.4846 - R_squared: 0.4860 - val_loss: 0.6350 - val_R_squared: 0.3800 - 165ms/epoch - 1ms/step
# Epoch 272/500
# 158/158 - 0s - loss: 0.4777 - R_squared: 0.4986 - val_loss: 0.6411 - val_R_squared: 0.3802 - 209ms/epoch - 1ms/step
# Epoch 273/500
# 158/158 - 0s - loss: 0.4745 - R_squared: 0.4931 - val_loss: 0.6519 - val_R_squared: 0.3696 - 152ms/epoch - 962us/step
# Epoch 274/500
# 158/158 - 0s - loss: 0.4697 - R_squared: 0.5118 - val_loss: 0.6216 - val_R_squared: 0.4075 - 163ms/epoch - 1ms/step
# Epoch 275/500
# 158/158 - 0s - loss: 0.4803 - R_squared: 0.4869 - val_loss: 0.6501 - val_R_squared: 0.3636 - 180ms/epoch - 1ms/step
# Epoch 276/500
# 158/158 - 0s - loss: 0.4774 - R_squared: 0.4890 - val_loss: 0.6285 - val_R_squared: 0.3983 - 182ms/epoch - 1ms/step
# Epoch 277/500
# 158/158 - 0s - loss: 0.4840 - R_squared: 0.4921 - val_loss: 0.6618 - val_R_squared: 0.3677 - 181ms/epoch - 1ms/step
# Epoch 278/500
# 158/158 - 0s - loss: 0.4776 - R_squared: 0.5083 - val_loss: 0.6373 - val_R_squared: 0.3915 - 191ms/epoch - 1ms/step
# Epoch 279/500
# 158/158 - 0s - loss: 0.4689 - R_squared: 0.5053 - val_loss: 0.6351 - val_R_squared: 0.3919 - 164ms/epoch - 1ms/step
# Epoch 280/500
# 158/158 - 0s - loss: 0.4817 - R_squared: 0.4912 - val_loss: 0.6194 - val_R_squared: 0.4043 - 169ms/epoch - 1ms/step
# Epoch 281/500
# 158/158 - 0s - loss: 0.4722 - R_squared: 0.4929 - val_loss: 0.6504 - val_R_squared: 0.3773 - 174ms/epoch - 1ms/step
# Epoch 282/500
# 158/158 - 0s - loss: 0.4733 - R_squared: 0.4972 - val_loss: 0.6337 - val_R_squared: 0.3941 - 183ms/epoch - 1ms/step
# Epoch 283/500
# 158/158 - 0s - loss: 0.4749 - R_squared: 0.5034 - val_loss: 0.6430 - val_R_squared: 0.3777 - 158ms/epoch - 1ms/step
# Epoch 284/500
# 158/158 - 0s - loss: 0.4773 - R_squared: 0.4944 - val_loss: 0.6293 - val_R_squared: 0.3913 - 166ms/epoch - 1ms/step
# Epoch 285/500
# 158/158 - 0s - loss: 0.4851 - R_squared: 0.4925 - val_loss: 0.6502 - val_R_squared: 0.3646 - 168ms/epoch - 1ms/step
# Epoch 286/500
# 158/158 - 0s - loss: 0.4787 - R_squared: 0.4812 - val_loss: 0.6246 - val_R_squared: 0.3925 - 185ms/epoch - 1ms/step
# Epoch 287/500
# 158/158 - 0s - loss: 0.4748 - R_squared: 0.4965 - val_loss: 0.6550 - val_R_squared: 0.3615 - 157ms/epoch - 995us/step
# Epoch 288/500
# 158/158 - 0s - loss: 0.4776 - R_squared: 0.4891 - val_loss: 0.6112 - val_R_squared: 0.4125 - 168ms/epoch - 1ms/step
# Epoch 289/500
# 158/158 - 0s - loss: 0.4699 - R_squared: 0.5003 - val_loss: 0.6107 - val_R_squared: 0.4088 - 164ms/epoch - 1ms/step
# Epoch 290/500
# 158/158 - 0s - loss: 0.4693 - R_squared: 0.4972 - val_loss: 0.6263 - val_R_squared: 0.4017 - 196ms/epoch - 1ms/step
# Epoch 291/500
# 158/158 - 0s - loss: 0.4715 - R_squared: 0.5067 - val_loss: 0.6246 - val_R_squared: 0.3940 - 168ms/epoch - 1ms/step
# Epoch 292/500
# 158/158 - 0s - loss: 0.4647 - R_squared: 0.5073 - val_loss: 0.6350 - val_R_squared: 0.3863 - 159ms/epoch - 1ms/step
# Epoch 293/500
# 158/158 - 0s - loss: 0.4675 - R_squared: 0.5013 - val_loss: 0.6367 - val_R_squared: 0.3855 - 216ms/epoch - 1ms/step
# Epoch 294/500
# 158/158 - 0s - loss: 0.4743 - R_squared: 0.4902 - val_loss: 0.6365 - val_R_squared: 0.3903 - 158ms/epoch - 1ms/step
# Epoch 295/500
# 158/158 - 0s - loss: 0.4609 - R_squared: 0.5052 - val_loss: 0.6228 - val_R_squared: 0.4004 - 167ms/epoch - 1ms/step
# Epoch 296/500
# 158/158 - 0s - loss: 0.4665 - R_squared: 0.5061 - val_loss: 0.6172 - val_R_squared: 0.4058 - 159ms/epoch - 1ms/step
# Epoch 297/500
# 158/158 - 0s - loss: 0.4717 - R_squared: 0.4944 - val_loss: 0.6613 - val_R_squared: 0.3521 - 193ms/epoch - 1ms/step
# Epoch 298/500
# 158/158 - 0s - loss: 0.4707 - R_squared: 0.5090 - val_loss: 0.6343 - val_R_squared: 0.3868 - 153ms/epoch - 967us/step
# Epoch 299/500
# 158/158 - 0s - loss: 0.4656 - R_squared: 0.5136 - val_loss: 0.6442 - val_R_squared: 0.3796 - 165ms/epoch - 1ms/step
# Epoch 300/500
# 158/158 - 0s - loss: 0.4674 - R_squared: 0.5075 - val_loss: 0.6287 - val_R_squared: 0.3948 - 166ms/epoch - 1ms/step
# Epoch 301/500
# 158/158 - 0s - loss: 0.4663 - R_squared: 0.5200 - val_loss: 0.6322 - val_R_squared: 0.3964 - 198ms/epoch - 1ms/step
# Epoch 302/500
# 158/158 - 0s - loss: 0.4658 - R_squared: 0.5077 - val_loss: 0.6479 - val_R_squared: 0.3889 - 156ms/epoch - 988us/step
# Epoch 303/500
# 158/158 - 0s - loss: 0.4597 - R_squared: 0.5178 - val_loss: 0.6841 - val_R_squared: 0.3246 - 161ms/epoch - 1ms/step
# Epoch 304/500
# 158/158 - 0s - loss: 0.4619 - R_squared: 0.5136 - val_loss: 0.6356 - val_R_squared: 0.3800 - 163ms/epoch - 1ms/step
# Epoch 305/500
# 158/158 - 0s - loss: 0.4676 - R_squared: 0.5048 - val_loss: 0.6292 - val_R_squared: 0.3880 - 165ms/epoch - 1ms/step
# Epoch 306/500
# 158/158 - 0s - loss: 0.4738 - R_squared: 0.5039 - val_loss: 0.6182 - val_R_squared: 0.3985 - 250ms/epoch - 2ms/step
# Epoch 307/500
# 158/158 - 0s - loss: 0.4630 - R_squared: 0.5140 - val_loss: 0.6327 - val_R_squared: 0.3954 - 163ms/epoch - 1ms/step
# Epoch 308/500
# 158/158 - 0s - loss: 0.4655 - R_squared: 0.5034 - val_loss: 0.6181 - val_R_squared: 0.4093 - 164ms/epoch - 1ms/step
# Epoch 309/500
# 158/158 - 0s - loss: 0.4643 - R_squared: 0.5022 - val_loss: 0.6052 - val_R_squared: 0.4161 - 170ms/epoch - 1ms/step
# Epoch 310/500
# 158/158 - 0s - loss: 0.4598 - R_squared: 0.5163 - val_loss: 0.6393 - val_R_squared: 0.3941 - 169ms/epoch - 1ms/step
# Epoch 311/500
# 158/158 - 0s - loss: 0.4619 - R_squared: 0.5091 - val_loss: 0.6173 - val_R_squared: 0.4065 - 170ms/epoch - 1ms/step
# Epoch 312/500
# 158/158 - 0s - loss: 0.4641 - R_squared: 0.5166 - val_loss: 0.6157 - val_R_squared: 0.4096 - 163ms/epoch - 1ms/step
# Epoch 313/500
# 158/158 - 0s - loss: 0.4571 - R_squared: 0.5180 - val_loss: 0.6294 - val_R_squared: 0.3953 - 160ms/epoch - 1ms/step
# Epoch 314/500
# 158/158 - 0s - loss: 0.4631 - R_squared: 0.5157 - val_loss: 0.6179 - val_R_squared: 0.4139 - 166ms/epoch - 1ms/step
# Epoch 315/500
# 158/158 - 0s - loss: 0.4632 - R_squared: 0.5019 - val_loss: 0.6196 - val_R_squared: 0.4082 - 167ms/epoch - 1ms/step
# Epoch 316/500
# 158/158 - 0s - loss: 0.4666 - R_squared: 0.5102 - val_loss: 0.6350 - val_R_squared: 0.3909 - 171ms/epoch - 1ms/step
# Epoch 317/500
# 158/158 - 0s - loss: 0.4635 - R_squared: 0.5153 - val_loss: 0.6389 - val_R_squared: 0.3826 - 168ms/epoch - 1ms/step
# Epoch 318/500
# 158/158 - 0s - loss: 0.4622 - R_squared: 0.5159 - val_loss: 0.6165 - val_R_squared: 0.4075 - 171ms/epoch - 1ms/step
# Epoch 319/500
# 158/158 - 0s - loss: 0.4664 - R_squared: 0.5103 - val_loss: 0.6166 - val_R_squared: 0.4128 - 169ms/epoch - 1ms/step
# Epoch 320/500
# 158/158 - 0s - loss: 0.4563 - R_squared: 0.5117 - val_loss: 0.6439 - val_R_squared: 0.3686 - 166ms/epoch - 1ms/step
# Epoch 321/500
# 158/158 - 0s - loss: 0.4642 - R_squared: 0.5051 - val_loss: 0.6179 - val_R_squared: 0.4019 - 165ms/epoch - 1ms/step
# Epoch 322/500
# 158/158 - 0s - loss: 0.4670 - R_squared: 0.5063 - val_loss: 0.6232 - val_R_squared: 0.3928 - 163ms/epoch - 1ms/step
# Epoch 323/500
# 158/158 - 0s - loss: 0.4625 - R_squared: 0.5037 - val_loss: 0.6583 - val_R_squared: 0.3700 - 165ms/epoch - 1ms/step
# Epoch 324/500
# 158/158 - 0s - loss: 0.4592 - R_squared: 0.5095 - val_loss: 0.6590 - val_R_squared: 0.3520 - 164ms/epoch - 1ms/step
# Epoch 325/500
# 158/158 - 0s - loss: 0.4552 - R_squared: 0.5120 - val_loss: 0.6192 - val_R_squared: 0.4122 - 166ms/epoch - 1ms/step
# Epoch 326/500
# 158/158 - 0s - loss: 0.4568 - R_squared: 0.5170 - val_loss: 0.6113 - val_R_squared: 0.4138 - 166ms/epoch - 1ms/step
# Epoch 327/500
# 158/158 - 0s - loss: 0.4581 - R_squared: 0.5032 - val_loss: 0.6174 - val_R_squared: 0.4071 - 161ms/epoch - 1ms/step
# Epoch 328/500
# 158/158 - 0s - loss: 0.4526 - R_squared: 0.5219 - val_loss: 0.6105 - val_R_squared: 0.4104 - 165ms/epoch - 1ms/step
# Epoch 329/500
# 158/158 - 0s - loss: 0.4532 - R_squared: 0.5243 - val_loss: 0.6192 - val_R_squared: 0.3984 - 158ms/epoch - 999us/step
# Epoch 330/500
# 158/158 - 0s - loss: 0.4559 - R_squared: 0.5240 - val_loss: 0.6226 - val_R_squared: 0.4047 - 167ms/epoch - 1ms/step
# Epoch 331/500
# 158/158 - 0s - loss: 0.4549 - R_squared: 0.5146 - val_loss: 0.6431 - val_R_squared: 0.3796 - 172ms/epoch - 1ms/step
# Epoch 332/500
# 158/158 - 0s - loss: 0.4537 - R_squared: 0.5175 - val_loss: 0.6243 - val_R_squared: 0.4033 - 165ms/epoch - 1ms/step
# Epoch 333/500
# 158/158 - 0s - loss: 0.4551 - R_squared: 0.5189 - val_loss: 0.6302 - val_R_squared: 0.3917 - 168ms/epoch - 1ms/step
# Epoch 334/500
# 158/158 - 0s - loss: 0.4541 - R_squared: 0.5109 - val_loss: 0.6188 - val_R_squared: 0.4057 - 171ms/epoch - 1ms/step
# Epoch 335/500
# 158/158 - 0s - loss: 0.4550 - R_squared: 0.5110 - val_loss: 0.6223 - val_R_squared: 0.3978 - 168ms/epoch - 1ms/step
# Epoch 336/500
# 158/158 - 0s - loss: 0.4519 - R_squared: 0.5277 - val_loss: 0.6244 - val_R_squared: 0.3947 - 164ms/epoch - 1ms/step
# Epoch 337/500
# 158/158 - 0s - loss: 0.4548 - R_squared: 0.5262 - val_loss: 0.6650 - val_R_squared: 0.3449 - 171ms/epoch - 1ms/step
# Epoch 338/500
# 158/158 - 0s - loss: 0.4566 - R_squared: 0.5138 - val_loss: 0.6377 - val_R_squared: 0.3913 - 166ms/epoch - 1ms/step
# Epoch 339/500
# 158/158 - 0s - loss: 0.4509 - R_squared: 0.5209 - val_loss: 0.6303 - val_R_squared: 0.3873 - 172ms/epoch - 1ms/step
# Epoch 340/500
# 158/158 - 0s - loss: 0.4597 - R_squared: 0.5121 - val_loss: 0.6218 - val_R_squared: 0.3969 - 165ms/epoch - 1ms/step
# Epoch 341/500
# 158/158 - 0s - loss: 0.4603 - R_squared: 0.5146 - val_loss: 0.6063 - val_R_squared: 0.4169 - 168ms/epoch - 1ms/step
# Epoch 342/500
# 158/158 - 0s - loss: 0.4518 - R_squared: 0.5236 - val_loss: 0.6445 - val_R_squared: 0.3660 - 175ms/epoch - 1ms/step
# Epoch 343/500
# 158/158 - 0s - loss: 0.4475 - R_squared: 0.5228 - val_loss: 0.6085 - val_R_squared: 0.4155 - 182ms/epoch - 1ms/step
# Epoch 344/500
# 158/158 - 0s - loss: 0.4520 - R_squared: 0.5185 - val_loss: 0.6220 - val_R_squared: 0.4062 - 159ms/epoch - 1ms/step
# Epoch 345/500
# 158/158 - 0s - loss: 0.4597 - R_squared: 0.5128 - val_loss: 0.6227 - val_R_squared: 0.3936 - 160ms/epoch - 1ms/step
# Epoch 346/500
# 158/158 - 0s - loss: 0.4524 - R_squared: 0.5226 - val_loss: 0.6065 - val_R_squared: 0.4137 - 164ms/epoch - 1ms/step
# Epoch 347/500
# 158/158 - 0s - loss: 0.4551 - R_squared: 0.5126 - val_loss: 0.6210 - val_R_squared: 0.3960 - 163ms/epoch - 1ms/step
# Epoch 348/500
# 158/158 - 0s - loss: 0.4498 - R_squared: 0.5225 - val_loss: 0.6203 - val_R_squared: 0.4028 - 166ms/epoch - 1ms/step
# Epoch 349/500
# 158/158 - 0s - loss: 0.4435 - R_squared: 0.5245 - val_loss: 0.6260 - val_R_squared: 0.3964 - 173ms/epoch - 1ms/step
# Epoch 350/500
# 158/158 - 0s - loss: 0.4591 - R_squared: 0.5146 - val_loss: 0.6145 - val_R_squared: 0.3964 - 181ms/epoch - 1ms/step
# Epoch 351/500
# 158/158 - 0s - loss: 0.4517 - R_squared: 0.5141 - val_loss: 0.6393 - val_R_squared: 0.3755 - 187ms/epoch - 1ms/step
# Epoch 352/500
# 158/158 - 0s - loss: 0.4525 - R_squared: 0.5101 - val_loss: 0.6375 - val_R_squared: 0.3860 - 173ms/epoch - 1ms/step
# Epoch 353/500
# 158/158 - 0s - loss: 0.4592 - R_squared: 0.5082 - val_loss: 0.6099 - val_R_squared: 0.4193 - 163ms/epoch - 1ms/step
# Epoch 354/500
# 158/158 - 0s - loss: 0.4531 - R_squared: 0.5293 - val_loss: 0.6143 - val_R_squared: 0.4041 - 162ms/epoch - 1ms/step
# Epoch 355/500
# 158/158 - 0s - loss: 0.4452 - R_squared: 0.5167 - val_loss: 0.6063 - val_R_squared: 0.4147 - 167ms/epoch - 1ms/step
# Epoch 356/500
# 158/158 - 0s - loss: 0.4504 - R_squared: 0.5228 - val_loss: 0.6217 - val_R_squared: 0.4009 - 165ms/epoch - 1ms/step
# Epoch 357/500
# 158/158 - 0s - loss: 0.4469 - R_squared: 0.5291 - val_loss: 0.6191 - val_R_squared: 0.4113 - 161ms/epoch - 1ms/step
# Epoch 358/500
# 158/158 - 0s - loss: 0.4491 - R_squared: 0.5262 - val_loss: 0.6281 - val_R_squared: 0.3974 - 167ms/epoch - 1ms/step
# Epoch 359/500
# 158/158 - 0s - loss: 0.4487 - R_squared: 0.5290 - val_loss: 0.6181 - val_R_squared: 0.4080 - 163ms/epoch - 1ms/step
# Epoch 360/500
# 158/158 - 0s - loss: 0.4506 - R_squared: 0.5153 - val_loss: 0.6524 - val_R_squared: 0.3664 - 170ms/epoch - 1ms/step
# Epoch 361/500
# 158/158 - 0s - loss: 0.4473 - R_squared: 0.5286 - val_loss: 0.6297 - val_R_squared: 0.3829 - 162ms/epoch - 1ms/step
# Epoch 362/500
# 158/158 - 0s - loss: 0.4554 - R_squared: 0.5196 - val_loss: 0.6173 - val_R_squared: 0.4013 - 156ms/epoch - 988us/step
# ...
# Epoch 378/500
# 158/158 - 0s - loss: 0.4517 - R_squared: 0.5264 - val_loss: 0.6016 - val_R_squared: 0.4205 - 175ms/epoch - 1ms/step
# Epoch 379/500
# 158/158 - 0s - loss: 0.4490 - R_squared: 0.5260 - val_loss: 0.6210 - val_R_squared: 0.3956 - 164ms/epoch - 1ms/step
# Epoch 380/500
# 158/158 - 0s - loss: 0.4453 - R_squared: 0.5357 - val_loss: 0.6426 - val_R_squared: 0.3674 - 165ms/epoch - 1ms/step
# Epoch 381/500
# 158/158 - 0s - loss: 0.4496 - R_squared: 0.5175 - val_loss: 0.6453 - val_R_squared: 0.3751 - 171ms/epoch - 1ms/step
# Epoch 382/500
# 158/158 - 0s - loss: 0.4419 - R_squared: 0.5349 - val_loss: 0.6125 - val_R_squared: 0.4109 - 198ms/epoch - 1ms/step
# Epoch 383/500
# 158/158 - 0s - loss: 0.4399 - R_squared: 0.5253 - val_loss: 0.6087 - val_R_squared: 0.4169 - 170ms/epoch - 1ms/step
# Epoch 384/500
# 158/158 - 0s - loss: 0.4412 - R_squared: 0.5354 - val_loss: 0.6224 - val_R_squared: 0.3948 - 165ms/epoch - 1ms/step
# Epoch 385/500
# 158/158 - 0s - loss: 0.4361 - R_squared: 0.5335 - val_loss: 0.6248 - val_R_squared: 0.3921 - 163ms/epoch - 1ms/step
# Epoch 386/500
# 158/158 - 0s - loss: 0.4405 - R_squared: 0.5285 - val_loss: 0.6099 - val_R_squared: 0.4124 - 168ms/epoch - 1ms/step
# Epoch 387/500
# 158/158 - 0s - loss: 0.4453 - R_squared: 0.5279 - val_loss: 0.6213 - val_R_squared: 0.4094 - 166ms/epoch - 1ms/step
# Epoch 388/500
# 158/158 - 0s - loss: 0.4466 - R_squared: 0.5265 - val_loss: 0.6328 - val_R_squared: 0.3854 - 161ms/epoch - 1ms/step
# Epoch 389/500
# 158/158 - 0s - loss: 0.4399 - R_squared: 0.5373 - val_loss: 0.5920 - val_R_squared: 0.4237 - 164ms/epoch - 1ms/step
# Epoch 390/500
# 158/158 - 0s - loss: 0.4346 - R_squared: 0.5386 - val_loss: 0.6213 - val_R_squared: 0.4089 - 166ms/epoch - 1ms/step
# Epoch 391/500
# 158/158 - 0s - loss: 0.4420 - R_squared: 0.5203 - val_loss: 0.6264 - val_R_squared: 0.3943 - 194ms/epoch - 1ms/step
# Epoch 392/500
# 158/158 - 0s - loss: 0.4383 - R_squared: 0.5281 - val_loss: 0.6258 - val_R_squared: 0.3886 - 182ms/epoch - 1ms/step
# Epoch 393/500
# 158/158 - 0s - loss: 0.4332 - R_squared: 0.5342 - val_loss: 0.6340 - val_R_squared: 0.3825 - 165ms/epoch - 1ms/step
# Epoch 394/500
# 158/158 - 0s - loss: 0.4398 - R_squared: 0.5345 - val_loss: 0.6089 - val_R_squared: 0.4138 - 184ms/epoch - 1ms/step
# Epoch 395/500
# 158/158 - 0s - loss: 0.4339 - R_squared: 0.5330 - val_loss: 0.6076 - val_R_squared: 0.4157 - 187ms/epoch - 1ms/step
# Epoch 396/500
# 158/158 - 0s - loss: 0.4405 - R_squared: 0.5325 - val_loss: 0.6180 - val_R_squared: 0.4098 - 179ms/epoch - 1ms/step
# Epoch 397/500
# 158/158 - 0s - loss: 0.4425 - R_squared: 0.5259 - val_loss: 0.6394 - val_R_squared: 0.3749 - 191ms/epoch - 1ms/step
# Epoch 398/500
# 158/158 - 0s - loss: 0.4381 - R_squared: 0.5396 - val_loss: 0.6628 - val_R_squared: 0.3474 - 187ms/epoch - 1ms/step
# Epoch 399/500
# 158/158 - 0s - loss: 0.4395 - R_squared: 0.5283 - val_loss: 0.6377 - val_R_squared: 0.3768 - 190ms/epoch - 1ms/step
# Epoch 400/500
# 158/158 - 0s - loss: 0.4361 - R_squared: 0.5381 - val_loss: 0.5999 - val_R_squared: 0.4179 - 195ms/epoch - 1ms/step
# Epoch 401/500
# 158/158 - 0s - loss: 0.4401 - R_squared: 0.5313 - val_loss: 0.6207 - val_R_squared: 0.4065 - 189ms/epoch - 1ms/step
# Epoch 402/500
# 158/158 - 0s - loss: 0.4325 - R_squared: 0.5508 - val_loss: 0.6238 - val_R_squared: 0.3894 - 278ms/epoch - 2ms/step
# Epoch 403/500
# 158/158 - 0s - loss: 0.4415 - R_squared: 0.5269 - val_loss: 0.6208 - val_R_squared: 0.3949 - 186ms/epoch - 1ms/step
# Epoch 404/500
# 158/158 - 0s - loss: 0.4428 - R_squared: 0.5190 - val_loss: 0.6146 - val_R_squared: 0.4145 - 182ms/epoch - 1ms/step
# Epoch 405/500
# 158/158 - 0s - loss: 0.4410 - R_squared: 0.5245 - val_loss: 0.6009 - val_R_squared: 0.4208 - 176ms/epoch - 1ms/step
# Epoch 406/500
# 158/158 - 0s - loss: 0.4287 - R_squared: 0.5407 - val_loss: 0.6345 - val_R_squared: 0.3774 - 172ms/epoch - 1ms/step
# Epoch 407/500
# 158/158 - 0s - loss: 0.4279 - R_squared: 0.5406 - val_loss: 0.6101 - val_R_squared: 0.4109 - 178ms/epoch - 1ms/step
# Epoch 408/500
# 158/158 - 0s - loss: 0.4367 - R_squared: 0.5352 - val_loss: 0.6319 - val_R_squared: 0.3848 - 162ms/epoch - 1ms/step
# Epoch 409/500
# 158/158 - 0s - loss: 0.4403 - R_squared: 0.5381 - val_loss: 0.6399 - val_R_squared: 0.3876 - 159ms/epoch - 1ms/step
# Epoch 410/500
# 158/158 - 0s - loss: 0.4420 - R_squared: 0.5346 - val_loss: 0.6272 - val_R_squared: 0.3922 - 190ms/epoch - 1ms/step
# Epoch 411/500
# 158/158 - 0s - loss: 0.4412 - R_squared: 0.5326 - val_loss: 0.6092 - val_R_squared: 0.4086 - 212ms/epoch - 1ms/step
# Epoch 412/500
# 158/158 - 0s - loss: 0.4379 - R_squared: 0.5310 - val_loss: 0.6258 - val_R_squared: 0.3948 - 193ms/epoch - 1ms/step
# Epoch 413/500
# 158/158 - 0s - loss: 0.4395 - R_squared: 0.5285 - val_loss: 0.5976 - val_R_squared: 0.4247 - 163ms/epoch - 1ms/step
# Epoch 414/500
# 158/158 - 0s - loss: 0.4352 - R_squared: 0.5274 - val_loss: 0.6169 - val_R_squared: 0.4082 - 168ms/epoch - 1ms/step
# Epoch 415/500
# 158/158 - 0s - loss: 0.4313 - R_squared: 0.5402 - val_loss: 0.6356 - val_R_squared: 0.3824 - 162ms/epoch - 1ms/step
# Epoch 416/500
# 158/158 - 0s - loss: 0.4265 - R_squared: 0.5411 - val_loss: 0.6127 - val_R_squared: 0.4079 - 168ms/epoch - 1ms/step
# Epoch 417/500
# 158/158 - 0s - loss: 0.4376 - R_squared: 0.5305 - val_loss: 0.6178 - val_R_squared: 0.4036 - 167ms/epoch - 1ms/step
# Epoch 418/500
# 158/158 - 0s - loss: 0.4453 - R_squared: 0.5268 - val_loss: 0.6210 - val_R_squared: 0.3970 - 172ms/epoch - 1ms/step
# Epoch 419/500
# 158/158 - 0s - loss: 0.4318 - R_squared: 0.5430 - val_loss: 0.6137 - val_R_squared: 0.4043 - 167ms/epoch - 1ms/step
# Epoch 420/500
# 158/158 - 0s - loss: 0.4360 - R_squared: 0.5445 - val_loss: 0.6093 - val_R_squared: 0.4150 - 166ms/epoch - 1ms/step
# Epoch 421/500
# 158/158 - 0s - loss: 0.4326 - R_squared: 0.5355 - val_loss: 0.6113 - val_R_squared: 0.4156 - 180ms/epoch - 1ms/step
# Epoch 422/500
# 158/158 - 0s - loss: 0.4298 - R_squared: 0.5476 - val_loss: 0.6434 - val_R_squared: 0.3678 - 169ms/epoch - 1ms/step
# Epoch 423/500
# 158/158 - 0s - loss: 0.4368 - R_squared: 0.5245 - val_loss: 0.6402 - val_R_squared: 0.3692 - 168ms/epoch - 1ms/step
# Epoch 424/500
# 158/158 - 0s - loss: 0.4293 - R_squared: 0.5394 - val_loss: 0.6049 - val_R_squared: 0.4179 - 164ms/epoch - 1ms/step
# Epoch 425/500
# 158/158 - 0s - loss: 0.4336 - R_squared: 0.5421 - val_loss: 0.6180 - val_R_squared: 0.4115 - 167ms/epoch - 1ms/step
# Epoch 426/500
# 158/158 - 0s - loss: 0.4427 - R_squared: 0.5278 - val_loss: 0.6659 - val_R_squared: 0.3530 - 166ms/epoch - 1ms/step
# Epoch 427/500
# 158/158 - 0s - loss: 0.4344 - R_squared: 0.5360 - val_loss: 0.6224 - val_R_squared: 0.3954 - 168ms/epoch - 1ms/step
# Epoch 428/500
# 158/158 - 0s - loss: 0.4277 - R_squared: 0.5353 - val_loss: 0.6264 - val_R_squared: 0.3876 - 169ms/epoch - 1ms/step
# Epoch 429/500
# 158/158 - 0s - loss: 0.4318 - R_squared: 0.5315 - val_loss: 0.6422 - val_R_squared: 0.3694 - 168ms/epoch - 1ms/step
# Epoch 430/500
# 158/158 - 0s - loss: 0.4310 - R_squared: 0.5403 - val_loss: 0.6025 - val_R_squared: 0.4197 - 162ms/epoch - 1ms/step
# Epoch 431/500
# 158/158 - 0s - loss: 0.4313 - R_squared: 0.5336 - val_loss: 0.6073 - val_R_squared: 0.4127 - 162ms/epoch - 1ms/step
# Epoch 432/500
# 158/158 - 0s - loss: 0.4371 - R_squared: 0.5336 - val_loss: 0.6343 - val_R_squared: 0.3799 - 164ms/epoch - 1ms/step
# Epoch 433/500
# 158/158 - 0s - loss: 0.4282 - R_squared: 0.5484 - val_loss: 0.6189 - val_R_squared: 0.3999 - 169ms/epoch - 1ms/step
# Epoch 434/500
# 158/158 - 0s - loss: 0.4400 - R_squared: 0.5314 - val_loss: 0.6121 - val_R_squared: 0.4044 - 174ms/epoch - 1ms/step
# Epoch 435/500
# 158/158 - 0s - loss: 0.4292 - R_squared: 0.5450 - val_loss: 0.6223 - val_R_squared: 0.3960 - 160ms/epoch - 1ms/step
# Epoch 436/500
# 158/158 - 0s - loss: 0.4248 - R_squared: 0.5445 - val_loss: 0.6323 - val_R_squared: 0.3881 - 169ms/epoch - 1ms/step
# Epoch 437/500
# 158/158 - 0s - loss: 0.4339 - R_squared: 0.5386 - val_loss: 0.6124 - val_R_squared: 0.4121 - 165ms/epoch - 1ms/step
# Epoch 438/500
# 158/158 - 0s - loss: 0.4228 - R_squared: 0.5382 - val_loss: 0.6021 - val_R_squared: 0.4145 - 167ms/epoch - 1ms/step
# Epoch 439/500
# 158/158 - 0s - loss: 0.4249 - R_squared: 0.5492 - val_loss: 0.6156 - val_R_squared: 0.4075 - 171ms/epoch - 1ms/step
# Epoch 440/500
# 158/158 - 0s - loss: 0.4255 - R_squared: 0.5492 - val_loss: 0.6344 - val_R_squared: 0.3784 - 164ms/epoch - 1ms/step
# Epoch 441/500
# 158/158 - 0s - loss: 0.4276 - R_squared: 0.5463 - val_loss: 0.6279 - val_R_squared: 0.3826 - 201ms/epoch - 1ms/step
# Epoch 442/500
# 158/158 - 0s - loss: 0.4357 - R_squared: 0.5274 - val_loss: 0.6203 - val_R_squared: 0.4094 - 171ms/epoch - 1ms/step
# Epoch 443/500
# 158/158 - 0s - loss: 0.4339 - R_squared: 0.5308 - val_loss: 0.6239 - val_R_squared: 0.3967 - 195ms/epoch - 1ms/step
# Epoch 444/500
# 158/158 - 0s - loss: 0.4337 - R_squared: 0.5417 - val_loss: 0.6038 - val_R_squared: 0.4095 - 169ms/epoch - 1ms/step
# Epoch 445/500
# 158/158 - 0s - loss: 0.4267 - R_squared: 0.5324 - val_loss: 0.6068 - val_R_squared: 0.4086 - 164ms/epoch - 1ms/step
# Epoch 446/500
# 158/158 - 0s - loss: 0.4334 - R_squared: 0.5399 - val_loss: 0.5959 - val_R_squared: 0.4261 - 172ms/epoch - 1ms/step
# Epoch 447/500
# 158/158 - 0s - loss: 0.4322 - R_squared: 0.5363 - val_loss: 0.6277 - val_R_squared: 0.3965 - 163ms/epoch - 1ms/step
# Epoch 448/500
# 158/158 - 0s - loss: 0.4255 - R_squared: 0.5532 - val_loss: 0.6171 - val_R_squared: 0.4072 - 170ms/epoch - 1ms/step
# Epoch 449/500
# 158/158 - 0s - loss: 0.4272 - R_squared: 0.5457 - val_loss: 0.6104 - val_R_squared: 0.4106 - 169ms/epoch - 1ms/step
# Epoch 450/500
# 158/158 - 0s - loss: 0.4333 - R_squared: 0.5383 - val_loss: 0.6315 - val_R_squared: 0.3874 - 162ms/epoch - 1ms/step
# Epoch 451/500
# 158/158 - 0s - loss: 0.4274 - R_squared: 0.5371 - val_loss: 0.6102 - val_R_squared: 0.4039 - 174ms/epoch - 1ms/step
# Epoch 452/500
# 158/158 - 0s - loss: 0.4223 - R_squared: 0.5633 - val_loss: 0.6133 - val_R_squared: 0.4036 - 175ms/epoch - 1ms/step
# Epoch 453/500
# 158/158 - 0s - loss: 0.4311 - R_squared: 0.5407 - val_loss: 0.6033 - val_R_squared: 0.4154 - 171ms/epoch - 1ms/step
# Epoch 454/500
# 158/158 - 0s - loss: 0.4281 - R_squared: 0.5451 - val_loss: 0.6320 - val_R_squared: 0.3992 - 167ms/epoch - 1ms/step
# Epoch 455/500
# 158/158 - 0s - loss: 0.4241 - R_squared: 0.5438 - val_loss: 0.6124 - val_R_squared: 0.4047 - 165ms/epoch - 1ms/step
# Epoch 456/500
# 158/158 - 0s - loss: 0.4261 - R_squared: 0.5452 - val_loss: 0.6238 - val_R_squared: 0.4088 - 168ms/epoch - 1ms/step
# Epoch 457/500
# 158/158 - 0s - loss: 0.4294 - R_squared: 0.5477 - val_loss: 0.6105 - val_R_squared: 0.4106 - 166ms/epoch - 1ms/step
# Epoch 458/500
# 158/158 - 0s - loss: 0.4309 - R_squared: 0.5395 - val_loss: 0.5971 - val_R_squared: 0.4227 - 175ms/epoch - 1ms/step
# Epoch 459/500
# 158/158 - 0s - loss: 0.4209 - R_squared: 0.5519 - val_loss: 0.6348 - val_R_squared: 0.3849 - 172ms/epoch - 1ms/step
# Epoch 460/500
# 158/158 - 0s - loss: 0.4250 - R_squared: 0.5508 - val_loss: 0.5993 - val_R_squared: 0.4186 - 178ms/epoch - 1ms/step
# Epoch 461/500
# 158/158 - 0s - loss: 0.4288 - R_squared: 0.5499 - val_loss: 0.6102 - val_R_squared: 0.4036 - 169ms/epoch - 1ms/step
# Epoch 462/500
# 158/158 - 0s - loss: 0.4297 - R_squared: 0.5452 - val_loss: 0.6190 - val_R_squared: 0.4076 - 163ms/epoch - 1ms/step
# Epoch 463/500
# 158/158 - 0s - loss: 0.4237 - R_squared: 0.5400 - val_loss: 0.6104 - val_R_squared: 0.4146 - 171ms/epoch - 1ms/step
# Epoch 464/500
# 158/158 - 0s - loss: 0.4156 - R_squared: 0.5567 - val_loss: 0.6130 - val_R_squared: 0.4094 - 165ms/epoch - 1ms/step
# Epoch 465/500
# 158/158 - 0s - loss: 0.4240 - R_squared: 0.5490 - val_loss: 0.6047 - val_R_squared: 0.4158 - 165ms/epoch - 1ms/step
# Epoch 466/500
# 158/158 - 0s - loss: 0.4258 - R_squared: 0.5466 - val_loss: 0.6079 - val_R_squared: 0.4165 - 170ms/epoch - 1ms/step
# Epoch 467/500
# 158/158 - 0s - loss: 0.4296 - R_squared: 0.5493 - val_loss: 0.6184 - val_R_squared: 0.3973 - 171ms/epoch - 1ms/step
# Epoch 468/500
# 158/158 - 0s - loss: 0.4292 - R_squared: 0.5451 - val_loss: 0.6217 - val_R_squared: 0.4005 - 180ms/epoch - 1ms/step
# Epoch 469/500
# 158/158 - 0s - loss: 0.4232 - R_squared: 0.5498 - val_loss: 0.6043 - val_R_squared: 0.4148 - 164ms/epoch - 1ms/step
# Epoch 470/500
# 158/158 - 0s - loss: 0.4233 - R_squared: 0.5411 - val_loss: 0.6343 - val_R_squared: 0.3893 - 177ms/epoch - 1ms/step
# Epoch 471/500
# 158/158 - 0s - loss: 0.4230 - R_squared: 0.5496 - val_loss: 0.6367 - val_R_squared: 0.3836 - 170ms/epoch - 1ms/step
# Epoch 472/500
# 158/158 - 0s - loss: 0.4206 - R_squared: 0.5490 - val_loss: 0.6016 - val_R_squared: 0.4183 - 162ms/epoch - 1ms/step
# Epoch 473/500
# 158/158 - 0s - loss: 0.4176 - R_squared: 0.5565 - val_loss: 0.6046 - val_R_squared: 0.4110 - 165ms/epoch - 1ms/step
# Epoch 474/500
# 158/158 - 0s - loss: 0.4192 - R_squared: 0.5463 - val_loss: 0.6102 - val_R_squared: 0.4052 - 167ms/epoch - 1ms/step
# Epoch 475/500
# 158/158 - 0s - loss: 0.4313 - R_squared: 0.5371 - val_loss: 0.6061 - val_R_squared: 0.4153 - 168ms/epoch - 1ms/step
# Epoch 476/500
# 158/158 - 0s - loss: 0.4248 - R_squared: 0.5505 - val_loss: 0.5993 - val_R_squared: 0.4188 - 170ms/epoch - 1ms/step
# Epoch 477/500
# 158/158 - 0s - loss: 0.4170 - R_squared: 0.5467 - val_loss: 0.6142 - val_R_squared: 0.4038 - 173ms/epoch - 1ms/step
# Epoch 478/500
# 158/158 - 0s - loss: 0.4152 - R_squared: 0.5595 - val_loss: 0.6197 - val_R_squared: 0.3985 - 173ms/epoch - 1ms/step
# Epoch 479/500
# 158/158 - 0s - loss: 0.4226 - R_squared: 0.5478 - val_loss: 0.6079 - val_R_squared: 0.4162 - 176ms/epoch - 1ms/step
# Epoch 480/500
# 158/158 - 0s - loss: 0.4167 - R_squared: 0.5527 - val_loss: 0.6106 - val_R_squared: 0.4036 - 180ms/epoch - 1ms/step
# Epoch 481/500
# 158/158 - 0s - loss: 0.4226 - R_squared: 0.5443 - val_loss: 0.6110 - val_R_squared: 0.4087 - 195ms/epoch - 1ms/step
# Epoch 482/500
# 158/158 - 0s - loss: 0.4159 - R_squared: 0.5529 - val_loss: 0.5969 - val_R_squared: 0.4274 - 174ms/epoch - 1ms/step
# Epoch 483/500
# 158/158 - 0s - loss: 0.4220 - R_squared: 0.5407 - val_loss: 0.6019 - val_R_squared: 0.4131 - 211ms/epoch - 1ms/step
# Epoch 484/500
# 158/158 - 0s - loss: 0.4204 - R_squared: 0.5545 - val_loss: 0.5916 - val_R_squared: 0.4333 - 199ms/epoch - 1ms/step
# Epoch 485/500
# 158/158 - 0s - loss: 0.4163 - R_squared: 0.5561 - val_loss: 0.6251 - val_R_squared: 0.3886 - 216ms/epoch - 1ms/step
# Epoch 486/500
# 158/158 - 0s - loss: 0.4215 - R_squared: 0.5484 - val_loss: 0.6043 - val_R_squared: 0.4130 - 255ms/epoch - 2ms/step
# Epoch 487/500
# 158/158 - 0s - loss: 0.4133 - R_squared: 0.5570 - val_loss: 0.6090 - val_R_squared: 0.4093 - 213ms/epoch - 1ms/step
# Epoch 488/500
# 158/158 - 0s - loss: 0.4227 - R_squared: 0.5533 - val_loss: 0.6209 - val_R_squared: 0.3902 - 167ms/epoch - 1ms/step
# Epoch 489/500
# 158/158 - 0s - loss: 0.4235 - R_squared: 0.5540 - val_loss: 0.6042 - val_R_squared: 0.4186 - 175ms/epoch - 1ms/step
# Epoch 490/500
# 158/158 - 0s - loss: 0.4156 - R_squared: 0.5507 - val_loss: 0.6189 - val_R_squared: 0.4060 - 194ms/epoch - 1ms/step
# Epoch 491/500
# 158/158 - 0s - loss: 0.4195 - R_squared: 0.5555 - val_loss: 0.5977 - val_R_squared: 0.4165 - 211ms/epoch - 1ms/step
# Epoch 492/500
# 158/158 - 0s - loss: 0.4155 - R_squared: 0.5545 - val_loss: 0.6218 - val_R_squared: 0.4039 - 206ms/epoch - 1ms/step
# Epoch 493/500
# 158/158 - 0s - loss: 0.4183 - R_squared: 0.5449 - val_loss: 0.6063 - val_R_squared: 0.4134 - 213ms/epoch - 1ms/step
# Epoch 494/500
# 158/158 - 0s - loss: 0.4175 - R_squared: 0.5462 - val_loss: 0.6083 - val_R_squared: 0.4060 - 182ms/epoch - 1ms/step
# Epoch 495/500
# 158/158 - 0s - loss: 0.4164 - R_squared: 0.5551 - val_loss: 0.7022 - val_R_squared: 0.2953 - 170ms/epoch - 1ms/step
# Epoch 496/500
# 158/158 - 0s - loss: 0.4177 - R_squared: 0.5614 - val_loss: 0.6142 - val_R_squared: 0.3975 - 188ms/epoch - 1ms/step
# Epoch 497/500
# 158/158 - 0s - loss: 0.4081 - R_squared: 0.5613 - val_loss: 0.6141 - val_R_squared: 0.4089 - 186ms/epoch - 1ms/step
# Epoch 498/500
# 158/158 - 0s - loss: 0.4209 - R_squared: 0.5502 - val_loss: 0.6051 - val_R_squared: 0.4144 - 163ms/epoch - 1ms/step
# Epoch 499/500
# 158/158 - 0s - loss: 0.4166 - R_squared: 0.5504 - val_loss: 0.5914 - val_R_squared: 0.4270 - 201ms/epoch - 1ms/step
# Epoch 500/500
# 158/158 - 0s - loss: 0.4164 - R_squared: 0.5537 - val_loss: 0.6074 - val_R_squared: 0.4135 - 172ms/epoch - 1ms/step

# %%
plt.subplots(figsize=(14,6))
plt.plot(network.history['R_squared'],label='Training')
plt.plot(network.history['val_R_squared'],label='Testing')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(loc='best',fontsize=20)
plt.title("Accuracy vs epochs");

# %%
plt.subplots(figsize=(14,6))
plt.plot(network.history['loss'],label='Training')
plt.plot(network.history['val_loss'],label='Testing')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc='best',fontsize=20)
plt.title("Loss vs epochs");

# %% [markdown]
# **The neural networks although improves the training R2 score over epochs, fails to improve the R2 score on test data.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **The temperature/ humidity features showed little to no pearson correlation w.r.t target variable (<1%), although being highly correlated within themselves.**
#
# 2. **The time zone of the day plays an important role in deciding power consumption of appliances.**
#
# 3. **The best Algorithm to use for this dataset is Extra Trees Regressor (tree based algorithm)**
#
# 4. **PCA helped us to reduce our feature set dimension considerably without affecting performance of our models significantly.**
#
# 5. **The untuned model was able to explain 64.1% of variance (R2 score = 0.641) on test set, while the tuned model was able to explain 64.3% of variance (R2 score = 0.643) on test set which is a tiny improvement of < 1 %**
#
# 6. **The least RMSE score on test data set is found to be around 0.6 by Extra trees regressor model, which is considerably good compared to other models.**
#
# 7. **Tree based models are by far the best model while dealing with data set that has most of its features having no linear correlation with target variable. For similar reasons, linear models such as linear regression, Ridge and Lasso perform the worst.**
